# %% [markdown]
# # 주식 시장 예측해보기
#
# resource: https://www.kaggle.com/faressayah/stock-market-analysis-prediction-using-lstm

# %% [markdown]
# #### 이번 실습에서는 주가 데이터를 예측하는 일을 해볼 것 입니다.
# #### RNN, LSTM, GRU, N-BEATS 모델을 통해 미래의 주가를 예측해봅시다.

# %% [markdown]
# # 1. Pandas 를 이용한 데이터 전처리 및 matplotlib, seaborn 을 이용한 데이터 시각화

# %%
from datetime import datetime
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# !pip install yfinance
import yfinance as yf
from datetime import datetime

# Apple, Google, Microsoft, Amazon 데이터를 수집해봅시다
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

end = datetime.now()
start = datetime(end.year - 10, end.month, end.day) # 오늘부터 이전 10년간의 데이터를 모아봅시다.

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end) # yfinance 라이브러리는 주식 데이터를 자동으로 다운로드 받게 해줍니다.
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.68-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.5 MB/s
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.7.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 11.1 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.7.1 requests-2.27.1 yfinance-0.1.68
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Let's go ahead and play aorund with the AAPL DataFrame to get a feel for the data

# %%
company_list = [AAPL, GOOG, MSFT, AMZN]
company_name = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)

# %% [markdown]
# 데이터는 6가지의 feature로 구성되어 있습니다.
# 1. Open(시작가)
# 2. High(최고가)
# 3. Low(최저가)
# 4. Close(종가)
# 5. Adj Close(조정된 종가)
# 6. Volume(거래량)

# %%
df
# Out:
#                    Open         High  ...     Volume  company_name
# Date                                  ...
# 2012-01-12    15.081429    15.103571  ...  212587200         APPLE
# 2012-01-13    14.989286    15.016071  ...  226021600         APPLE
# 2012-01-17    15.150000    15.213929  ...  242897200         APPLE
# 2012-01-18    15.248571    15.338214  ...  276791200         APPLE
# 2012-01-19    15.362500    15.406071  ...  261738400         APPLE
# ...                 ...          ...  ...        ...           ...
# 2022-01-05  3337.659912  3342.530029  ...    3215100        AMAZON
# 2022-01-06  3269.010010  3296.000000  ...    2597900        AMAZON
# 2022-01-07  3276.780029  3304.870117  ...    2329300        AMAZON
# 2022-01-10  3211.709961  3233.229980  ...    4389900        AMAZON
# 2022-01-11  3230.000000  3327.000000  ...    3131500        AMAZON
#
# [10068 rows x 7 columns]

# %%
# Summary Stats
AAPL.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  2517.000000  2517.000000  ...  2517.000000  2.517000e+03
# mean     49.462477    49.981625  ...    47.737024  2.145457e+08
# std      39.220763    39.693572  ...    39.903133  1.759101e+08
# min      13.856071    14.271429  ...    12.134606  4.100000e+07
# 25%      23.732500    23.934999  ...    21.353046  1.027696e+08
# 50%      32.517502    32.735001  ...    29.691393  1.506940e+08
# 75%      54.447498    55.112499  ...    52.694386  2.644760e+08
# max     182.630005   182.940002  ...   182.009995  1.506120e+09
#
# [8 rows x 6 columns]

# %%
# General info
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2012-01-12 to 2022-01-11
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2517 non-null   float64
#  1   High          2517 non-null   float64
#  2   Low           2517 non-null   float64
#  3   Close         2517 non-null   float64
#  4   Adj Close     2517 non-null   float64
#  5   Volume        2517 non-null   int64
#  6   company_name  2517 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 157.3+ KB

# %%
# 과거의 종가 데이터를 한번 확인해봅시다.


plt.figure(figsize=(15, 6))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
# 과거의 거래량을 확인해봅시다.
plt.figure(figsize=(15, 7))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
df.groupby("company_name").hist(figsize=(12, 12))
# Out:
# company_name
# AMAZON       [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# APPLE        [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# GOOGLE       [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# MICROSOFT    [[AxesSubplot(0.125,0.670278;0.336957x0.209722...
# dtype: object

# %% [markdown]
# # 2. Moving average를 통해 데이터의 변화 양상을 확인해봅시다.

# %%
ma_day = [10, 20, 50] # 10일치, 20일치, 50일치의 moving average를 통해 변화양상을 확인해봅시다.

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# %%
print(GOOG.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'company_name',
#        'MA for 10 days', 'MA for 20 days', 'MA for 50 days'],
#       dtype='object')

# %% [markdown]
# - moving average에 사용되는 window의 크기가 클수록 더 긴 기간의 trend를 확인할 수 있고, window의 크기가 작을수록 짧은 구간의 trend 변화를 확인할 수 있습니다.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

plot_columns = ['Adj Close', 'MA for 10 days'] #, 'MA for 20 days', 'MA for 50 days']

AAPL[plot_columns].plot(ax=axes[0,0])   #.iloc[-500:].plot(ax=axes[0,0])
axes[0,0].set_title('APPLE')

GOOG[plot_columns].plot(ax=axes[0,1])
axes[0,1].set_title('GOOGLE')

MSFT[plot_columns].plot(ax=axes[1,0])
axes[1,0].set_title('MICROSOFT')

AMZN[plot_columns].plot(ax=axes[1,1])
axes[1,1].set_title('AMAZON')

fig.tight_layout()

# %% [markdown]
# # 3. 수익률을 분석해봅시다.
# - Pandas dataframe 은 pct_change 라는 수익률 분석 함수를 제공합니다. 이 함수는 아래의 값을 계산합니다.
#     - (현재 값 - 직전 값)/직전 값
#     - 종가에 적용하면 전날 종가대비 당일의 종가가 얼마나 상승했는지를 비율로 나타내게 됩니다.

# %%
# We'll use pct_change to find the percent change for each day
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

AAPL['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('APPLE')

GOOG['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('GOOGLE')

MSFT['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('MICROSOFT')

AMZN['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('AMAZON')

fig.tight_layout()

# %% [markdown]
# - Histogram 을 이용해서도 분석해봅시다. (Seaborn 라이브러리 이용)

# %%
plt.figure(figsize=(12, 7))

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    sns.distplot(company['Daily Return'].dropna(), bins=100, color='purple') # nan value는 seaborn 에서 읽을 수 없으므로 dropna 를 통해 처리하였습니다.
    plt.ylabel('Daily Return')
    plt.title(f'{company_name[i - 1]}')
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# pandas dataframe 에서 제공하는 histogram 함수를 사용해도 됩니다.
AAPL['Daily Return'].hist()

# %% [markdown]
# # 4. 서로 다른 주식의 종가들 간의 관계성을 분석해봅시다.

# %% [markdown]
# Now that we have all the closing prices, let's go ahead and get the daily return for all the stocks, like we did for the Apple stock.

# %%
closing_df = pd.DataFrame([AAPL['Adj Close'], GOOG['Adj Close'], MSFT['Adj Close'], AMZN['Adj Close']]).T
closing_df.columns = ['AAPL','GOOG','MSFT','AMZN']

# %%
# Make a new tech returns DataFrame
tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
#                 AAPL      GOOG      MSFT      AMZN
# Date
# 2012-01-12       NaN       NaN       NaN       NaN
# 2012-01-13 -0.003749 -0.007385  0.008928  0.014153
# 2012-01-17  0.011648  0.005744  0.000354  0.018159
# 2012-01-18  0.010384  0.006889 -0.001062  0.042827
# 2012-01-19 -0.003169  0.010523 -0.003896  0.026446

# %% [markdown]
# - seaborn 라이브러리의 jointplot을 통해 관계성을 분석해봅시다.

# %%
# 자기 자신과의 비교를 먼저 진행해봅시다. 자기 자신과 비교하면 correlation이 아주 강하게 나타나는 것을 볼 수 있습니다. (correlation = 1.0, 정비례)
sns.jointplot('GOOG', 'GOOG', tech_rets, kind='scatter', color='seagreen')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Google 과 Microsoft를 비교해봅시다.
sns.jointplot('GOOG', 'MSFT', tech_rets, kind='scatter')

"""
결과를 통해 아래의 질문에 답을 해보세요.
1. correlation이 높은가요? 아니면 낮은가요?
2. 그렇다면 Google 주식을 feature로 사용하면 Microsoft 주식을 예측할 때 도움이 될까요?
"""
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# '\n결과를 통해 아래의 질문에 답을 해보세요.\n1. correlation이 높은가요? 아니면 낮은가요?\n2. 그렇다면 Google 주식을 feature로 사용하면 Microsoft 주식을 예측할 때 도움이 될까요?\n'

# %% [markdown]
# - Pandas와 seaborn을 혼합하면 이러한 분석을 모든 pair에 대해 아주 쉽게 적용할 수 있습니다.

# %%
# We can simply call pairplot on our DataFrame for an automatic visual analysis 
# of all the comparisons

sns.pairplot(tech_rets, kind='reg')

# %% [markdown]
# - Seaborn 의 pairplot은 pairgrid 함수를 통해 좀 더 다양한 버전으로 적용될 수 있습니다. 이를 통해 다양한 방식으로 데이터를 분석하는 것이 가능합니다.
#     - 여기서는 이를 통해 분석을 진행하기보다는, 사용하는 방법에 대해서만 확인하고 넘어가도록 하겠습니다.
#     - 이 예제에서는 위쪽 삼각형에서는 scatter plot, 아래쪽 삼각형에서는 kernel density estimation plot, 대각에는 histogram을 그려보겠습니다.

# %%
# 우선, 수익률을 통해 분석해봅시다.
return_fig = sns.PairGrid(tech_rets.dropna())

return_fig.map_upper(plt.scatter, color='purple')
return_fig.map_lower(sns.kdeplot, cmap='cool_d') # kde 에서 회색 선은 등고선을 의미합니다
return_fig.map_diag(plt.hist, bins=30)

# %%
# 종가 데이터를 통해 분석해봅시다.
returns_fig = sns.PairGrid(closing_df)

returns_fig.map_upper(plt.scatter,color='purple')
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=30)

# %% [markdown]
# - pandas 의 corr 함수를 통해 pearson correlation을 간단히 계산할 수도 있습니다.

# %%
sns.heatmap(tech_rets.corr(), annot=True, cmap='viridis')

# %%
sns.heatmap(closing_df.corr(), annot=True, cmap='viridis')

# %% [markdown]
# # 5. Apple, Google, Microsoft, Amazon의 주식 종가를 예측해봅시다.

# %%
df = closing_df

# %%
df.columns
# Out:
# Index(['AAPL', 'GOOG', 'MSFT', 'AMZN'], dtype='object')

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['AAPL'], label='Apple')
plt.plot(df['GOOG'], label='Google')
plt.plot(df['MSFT'], label='Microsoft')
plt.plot(df['AMZN'], label='Amazon')
plt.legend(loc='upper left')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %% [markdown]
# # 5-1. 데이터 전처리

# %%
# data split 
train_data_length = int(len(df) * 0.8)
val_data_length = int(len(df) * 0.1)

train_df = df.iloc[:train_data_length]
val_df = df.iloc[train_data_length:train_data_length+val_data_length]
test_df = df.iloc[train_data_length+val_data_length:]

# %%
train_df.shape, val_df.shape, test_df.shape
# Out:
# ((2013, 4), (251, 4), (253, 4))

# %% [markdown]
# # 5-2. Dataset class 만들기, Dataloader 만들기

# %%
class StandardScaler():
    def __init__(self):
        self.mean = None
        self.stdev = None
        
    def fit(self, x, dim=None):
        if not torch.is_tensor(x): # numpy array -> torch tensor 
            x = torch.tensor(x)# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        
        if dim is not None:
            self.mean = x.mean(dim)
            self.stdev = x.std(dim)
        else:
            self.mean = x.mean()
            self.stdev = x.std()
        
    def scale(self, x):# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        if not torch.is_tensor(x): # numpy array -> torch tensor 
            x = torch.tensor(x)
        return (x - self.mean.to(x.device)) / self.stdev.to(x.device)
    
    def unscale(self, x):
        if not torch.is_tensor(x): # numpy array -> torch tensor 
            x = torch.tensor(x)
        return x * self.stdev.to(x.device) + self.mean.to(x.device)
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

class TimeseriesDataset(torch.utils.data.Dataset):   
    def __init__(self, data, backcast_length, forecast_length, scaler=None):
        self.data_columns = data.columns
        self.data = data.values
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        
        if scaler is None:
            # train
            self.scaler = StandardScaler()
            self.scaler.fit(self.data, dim=0)
        else:
            self.scaler = scaler
        self.data = self.scaler.scale(self.data)
        

    def __len__(self):
        return len(self.data) - self.backcast_length - self.forecast_length + 1

    def __getitem__(self, idx):
        x_end = idx + self.backcast_length
        y_end = x_end + self.forecast_length

        x = self.data[idx:x_end]
        y = self.data[x_end:y_end]
        
        x = x.float()
        y = y.float()
        
        return x, y 
    
    def unscale(self, x):
        return self.scaler.unscale(x)

# %%
batch_size = 128
num_workers = 2
pin_memory = True

backcast_length = 30
forecast_length = 30

# %%
train_dataset = TimeseriesDataset(train_df, backcast_length, forecast_length, scaler=None)
val_dataset = TimeseriesDataset(val_df, backcast_length, forecast_length, scaler=train_dataset.scaler)
test_dataset = TimeseriesDataset(test_df, backcast_length, forecast_length, scaler=train_dataset.scaler)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, 
                                               num_workers=num_workers, pin_memory=pin_memory)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False, 
                                               num_workers=num_workers, pin_memory=pin_memory)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, 
                                               num_workers=num_workers, pin_memory=pin_memory)

# %% [markdown]
# # 5-3. 모델 정의하기

# %%
class RNNmodel(nn.Module):
    def __init__(self, feature_dim, hidden_dim, LSTM=False, GRU=False, num_layers=4, bidirectional=False, dropout=0.3, batch_first=True, backcast_length=30, forecast_length=30):
        super(RNNmodel, self).__init__()
        self.LSTM = LSTM # LSTM인지 아닌지 여부를 저장해둡니다.
        self.n_direction = 2 if bidirectional else 1
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        self.num_layers = num_layers
        self.hidden_dim = hidden_dim
        
        
        if LSTM:
            rnn = nn.LSTM
        elif GRU:
            rnn = nn.GRU
        else:
            rnn = nn.RNN
            
            
        self.rnn = rnn(input_size = feature_dim, 
                       hidden_size = hidden_dim, 
                       num_layers = num_layers,
                       bias = True,
                       batch_first = batch_first,
                       dropout = dropout,
                       bidirectional = bidirectional)# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        self.out = nn.Linear(hidden_dim * self.n_direction, feature_dim)
        
    def forward(self, x):
        # x: (batch, sequence length, feature_dim)
        
        
        # many to many 구조를 구현해봅시다.
        
        if self.LSTM:
            h0 = (torch.zeros(self.num_layers * self.n_direction, x.shape[0], self.hidden_dim, device=x.device),
                  torch.zeros(self.num_layers * self.n_direction, x.shape[0], self.hidden_dim, device=x.device))
        else:
            h0 = torch.zeros(self.num_layers * self.n_direction, x.shape[0], self.hidden_dim, device=x.device)
        
        x, h = self.rnn(x, h0)
        outs = []
        for i in range(self.forecast_length):
            x = self.out(x[:,-1:,:])
            outs.append(x.squeeze(1))
            
            if i == self.forecast_length-1:
                break
                
            x, h = self.rnn(x, h)
            
        outs = torch.stack(outs, dim=1)
        return outs

# %%
feature_dim=4
hidden_dim=64

model = RNNmodel(feature_dim, hidden_dim, LSTM=False, GRU=True)

# %% [markdown]
# # 5-4. 학습 방식 정의하기

# %%
learning_rate = 1e-4

criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # 5-5. 학습 진행하기

# %%
num_epoch = 100



import time
train_losses = []
val_losses = []
best_epoch = 0
start_time = time.time()
best_model_state_dict = None
best_val_loss = 10000
for epoch in range(num_epoch):
    train_loss_mean = 0
    val_loss_mean = 0
    
    # train
    model.train()
    for i, (inputs, labels) in enumerate(train_dataloader):
#         inputs = inputs.cuda()
#         labels = labels.cuda()
        
        forecast = model(inputs)
    
        forecast = model(inputs)
        loss = criterion(forecast.sum(0), labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss_mean += loss.item()
        
        if i % 100 == 0:
            print('epoch [{}/{}] iter [{:03d}/{:03d}] loss [{:.4f}] elapsed time [{:.2f}min]'.format(epoch, num_epoch, i, len(train_dataloader), loss.item(), (time.time()-start_time)/60))
    
    train_loss_mean = train_loss_mean/len(train_dataloader)
    
    train_losses.append(train_loss_mean)
    
    # validation
    model.eval()
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_dataloader):
#             inputs = inputs.cuda()
#             labels = labels.cuda()

            forecast = model(inputs)
            loss = criterion(forecast.sum(0), labels)
            val_loss_mean += loss.item()

        val_loss_mean = val_loss_mean/len(val_dataloader)

        print('epoch [{}/{}] train loss [{:.4f}] validation loss [{:.4f}] elapsed time [{:.2f} min]\n'.format(epoch, num_epoch, train_loss_mean, val_loss_mean, (time.time()-start_time)/60))

        if val_loss_mean < best_val_loss:
            best_epoch = epoch
            best_val_loss = val_loss_mean
            best_model_state_dict = model.state_dict()
    val_losses.append(val_loss_mean)# We can simply call pairplot on our DataFrame for an automatic visual analysis
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:96: UserWarning: Using a target size (torch.Size([128, 30, 4])) that is different to the input size (torch.Size([30, 4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# epoch [0/100] iter [000/016] loss [6.5268] elapsed time [0.15min]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:96: UserWarning: Using a target size (torch.Size([34, 30, 4])) that is different to the input size (torch.Size([30, 4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# epoch [0/100] train loss [3.5525] validation loss [5.0312] elapsed time [0.24 min]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:96: UserWarning: Using a target size (torch.Size([64, 30, 4])) that is different to the input size (torch.Size([30, 4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# epoch [1/100] iter [000/016] loss [0.9069] elapsed time [0.25min]
# epoch [1/100] train loss [1.0885] validation loss [5.1800] elapsed time [0.34 min]
#
# epoch [2/100] iter [000/016] loss [0.7778] elapsed time [0.35min]
# epoch [2/100] train loss [0.8617] validation loss [4.8046] elapsed time [0.44 min]
#
# epoch [3/100] iter [000/016] loss [0.8813] elapsed time [0.45min]
# epoch [3/100] train loss [0.8550] validation loss [4.9802] elapsed time [0.54 min]
#
# epoch [4/100] iter [000/016] loss [0.8153] elapsed time [0.55min]
# epoch [4/100] train loss [0.8090] validation loss [5.0199] elapsed time [0.64 min]
#
# epoch [5/100] iter [000/016] loss [0.7332] elapsed time [0.65min]
# epoch [5/100] train loss [0.8098] validation loss [4.8486] elapsed time [0.74 min]
#
# epoch [6/100] iter [000/016] loss [0.7816] elapsed time [0.76min]
# epoch [6/100] train loss [0.8085] validation loss [4.8181] elapsed time [0.85 min]
#
# epoch [7/100] iter [000/016] loss [0.8345] elapsed time [0.86min]
# epoch [7/100] train loss [0.8128] validation loss [4.7106] elapsed time [0.95 min]
#
# epoch [8/100] iter [000/016] loss [0.7834] elapsed time [0.96min]
# epoch [8/100] train loss [0.8035] validation loss [4.6856] elapsed time [1.05 min]
#
# epoch [9/100] iter [000/016] loss [0.7867] elapsed time [1.06min]
# epoch [9/100] train loss [0.8098] validation loss [4.7808] elapsed time [1.15 min]
#
# epoch [10/100] iter [000/016] loss [0.7245] elapsed time [1.16min]
# epoch [10/100] train loss [0.8111] validation loss [4.5765] elapsed time [1.25 min]
#
# epoch [11/100] iter [000/016] loss [0.9115] elapsed time [1.26min]
# epoch [11/100] train loss [0.8037] validation loss [4.5230] elapsed time [1.35 min]
#
# epoch [12/100] iter [000/016] loss [0.8449] elapsed time [1.36min]
# epoch [12/100] train loss [0.8110] validation loss [4.5468] elapsed time [1.45 min]
#
# epoch [13/100] iter [000/016] loss [0.8640] elapsed time [1.46min]
# epoch [13/100] train loss [0.8062] validation loss [4.4460] elapsed time [1.55 min]
#
# epoch [14/100] iter [000/016] loss [0.8507] elapsed time [1.56min]
# epoch [14/100] train loss [0.8043] validation loss [4.3684] elapsed time [1.65 min]
#
# epoch [15/100] iter [000/016] loss [0.8699] elapsed time [1.67min]
# epoch [15/100] train loss [0.8086] validation loss [4.2379] elapsed time [1.76 min]
#
# epoch [16/100] iter [000/016] loss [0.7770] elapsed time [1.77min]
# epoch [16/100] train loss [0.8075] validation loss [4.1967] elapsed time [1.86 min]
#
# epoch [17/100] iter [000/016] loss [0.7546] elapsed time [1.87min]
# epoch [17/100] train loss [0.8061] validation loss [4.2047] elapsed time [1.96 min]
#
# epoch [18/100] iter [000/016] loss [0.7800] elapsed time [1.97min]
# epoch [18/100] train loss [0.8025] validation loss [4.1225] elapsed time [2.06 min]
#
# epoch [19/100] iter [000/016] loss [0.7543] elapsed time [2.07min]
# epoch [19/100] train loss [0.8114] validation loss [4.0954] elapsed time [2.16 min]
#
# epoch [20/100] iter [000/016] loss [0.8680] elapsed time [2.17min]
# epoch [20/100] train loss [0.8047] validation loss [3.9232] elapsed time [2.26 min]
#
# epoch [21/100] iter [000/016] loss [0.8219] elapsed time [2.27min]
# epoch [21/100] train loss [0.8132] validation loss [3.9536] elapsed time [2.37 min]
#
# epoch [22/100] iter [000/016] loss [0.7884] elapsed time [2.38min]
# epoch [22/100] train loss [0.8033] validation loss [3.9359] elapsed time [2.47 min]
#
# epoch [23/100] iter [000/016] loss [0.8149] elapsed time [2.48min]
# epoch [23/100] train loss [0.8084] validation loss [4.0314] elapsed time [2.57 min]
#
# epoch [24/100] iter [000/016] loss [0.7930] elapsed time [2.58min]
# epoch [24/100] train loss [0.8098] validation loss [3.9932] elapsed time [2.67 min]
#
# epoch [25/100] iter [000/016] loss [0.8291] elapsed time [2.68min]
# epoch [25/100] train loss [0.8032] validation loss [3.9144] elapsed time [2.77 min]
#
# epoch [26/100] iter [000/016] loss [0.8910] elapsed time [2.79min]
# epoch [26/100] train loss [0.8000] validation loss [3.9544] elapsed time [2.88 min]
#
# epoch [27/100] iter [000/016] loss [0.8667] elapsed time [2.89min]
# epoch [27/100] train loss [0.8082] validation loss [3.8408] elapsed time [2.98 min]
#
# epoch [28/100] iter [000/016] loss [0.7559] elapsed time [2.99min]
# epoch [28/100] train loss [0.7995] validation loss [3.9085] elapsed time [3.08 min]
#
# epoch [29/100] iter [000/016] loss [0.7756] elapsed time [3.09min]
# epoch [29/100] train loss [0.8096] validation loss [3.7674] elapsed time [3.18 min]
#
# epoch [30/100] iter [000/016] loss [0.8023] elapsed time [3.19min]
# epoch [30/100] train loss [0.8062] validation loss [3.8181] elapsed time [3.28 min]
#
# epoch [31/100] iter [000/016] loss [0.7991] elapsed time [3.29min]
# epoch [31/100] train loss [0.8109] validation loss [3.8242] elapsed time [3.38 min]
#
# epoch [32/100] iter [000/016] loss [0.8377] elapsed time [3.39min]
# epoch [32/100] train loss [0.7981] validation loss [3.8758] elapsed time [3.48 min]
#
# epoch [33/100] iter [000/016] loss [0.8407] elapsed time [3.49min]
# epoch [33/100] train loss [0.8061] validation loss [4.0057] elapsed time [3.58 min]
#
# epoch [34/100] iter [000/016] loss [0.8754] elapsed time [3.60min]
# epoch [34/100] train loss [0.8098] validation loss [3.8334] elapsed time [3.69 min]
#
# epoch [35/100] iter [000/016] loss [0.8490] elapsed time [3.70min]
# epoch [35/100] train loss [0.8134] validation loss [3.8083] elapsed time [3.79 min]
#
# epoch [36/100] iter [000/016] loss [0.8288] elapsed time [3.80min]
# epoch [36/100] train loss [0.8014] validation loss [3.6442] elapsed time [3.89 min]
#
# epoch [37/100] iter [000/016] loss [0.8608] elapsed time [3.90min]
# epoch [37/100] train loss [0.8010] validation loss [3.7227] elapsed time [3.99 min]
#
# epoch [38/100] iter [000/016] loss [0.8403] elapsed time [4.00min]
# epoch [38/100] train loss [0.8025] validation loss [3.6647] elapsed time [4.09 min]
#
# epoch [39/100] iter [000/016] loss [0.7722] elapsed time [4.10min]
# epoch [39/100] train loss [0.8132] validation loss [3.6446] elapsed time [4.19 min]
#
# epoch [40/100] iter [000/016] loss [0.7257] elapsed time [4.20min]
# epoch [40/100] train loss [0.8055] validation loss [3.6525] elapsed time [4.29 min]
#
# epoch [41/100] iter [000/016] loss [0.7879] elapsed time [4.30min]
# epoch [41/100] train loss [0.7999] validation loss [3.6409] elapsed time [4.39 min]
#
# epoch [42/100] iter [000/016] loss [0.7573] elapsed time [4.40min]
# epoch [42/100] train loss [0.8073] validation loss [3.7420] elapsed time [4.49 min]
#
# epoch [43/100] iter [000/016] loss [0.7874] elapsed time [4.50min]
# epoch [43/100] train loss [0.7982] validation loss [3.7166] elapsed time [4.59 min]
#
# epoch [44/100] iter [000/016] loss [0.7076] elapsed time [4.61min]
# epoch [44/100] train loss [0.8053] validation loss [3.7745] elapsed time [4.70 min]
#
# epoch [45/100] iter [000/016] loss [0.7801] elapsed time [4.71min]
# epoch [45/100] train loss [0.8144] validation loss [3.6331] elapsed time [4.80 min]
#
# epoch [46/100] iter [000/016] loss [0.7968] elapsed time [4.81min]
# epoch [46/100] train loss [0.8087] validation loss [3.8187] elapsed time [4.90 min]
#
# epoch [47/100] iter [000/016] loss [0.6755] elapsed time [4.91min]
# epoch [47/100] train loss [0.8051] validation loss [3.7350] elapsed time [5.00 min]
#
# epoch [48/100] iter [000/016] loss [0.8400] elapsed time [5.01min]
# epoch [48/100] train loss [0.7997] validation loss [3.6538] elapsed time [5.10 min]
#
# epoch [49/100] iter [000/016] loss [0.7959] elapsed time [5.11min]
# epoch [49/100] train loss [0.8065] validation loss [3.6944] elapsed time [5.20 min]
#
# epoch [50/100] iter [000/016] loss [0.7321] elapsed time [5.21min]
# epoch [50/100] train loss [0.8032] validation loss [3.7425] elapsed time [5.30 min]
#
# epoch [51/100] iter [000/016] loss [0.7798] elapsed time [5.32min]
# epoch [51/100] train loss [0.8025] validation loss [3.7697] elapsed time [5.40 min]
#
# epoch [52/100] iter [000/016] loss [0.8369] elapsed time [5.42min]
# epoch [52/100] train loss [0.8047] validation loss [3.7551] elapsed time [5.51 min]
#
# epoch [53/100] iter [000/016] loss [0.8700] elapsed time [5.52min]
# epoch [53/100] train loss [0.8040] validation loss [3.5985] elapsed time [5.61 min]
#
# epoch [54/100] iter [000/016] loss [0.8201] elapsed time [5.62min]
# epoch [54/100] train loss [0.7984] validation loss [3.7047] elapsed time [5.71 min]
#
# epoch [55/100] iter [000/016] loss [0.8987] elapsed time [5.72min]
# epoch [55/100] train loss [0.7978] validation loss [3.6169] elapsed time [5.81 min]
#
# epoch [56/100] iter [000/016] loss [0.8750] elapsed time [5.82min]
# epoch [56/100] train loss [0.8046] validation loss [3.5206] elapsed time [5.91 min]
#
# epoch [57/100] iter [000/016] loss [0.8435] elapsed time [5.92min]
# epoch [57/100] train loss [0.8044] validation loss [3.4565] elapsed time [6.02 min]
#
# epoch [58/100] iter [000/016] loss [0.8792] elapsed time [6.03min]
# epoch [58/100] train loss [0.8085] validation loss [3.5812] elapsed time [6.12 min]
#
# epoch [59/100] iter [000/016] loss [0.8398] elapsed time [6.13min]
# epoch [59/100] train loss [0.8041] validation loss [3.4898] elapsed time [6.22 min]
#
# epoch [60/100] iter [000/016] loss [0.7812] elapsed time [6.23min]
# epoch [60/100] train loss [0.8076] validation loss [3.5024] elapsed time [6.32 min]
#
# epoch [61/100] iter [000/016] loss [0.7786] elapsed time [6.33min]
# epoch [61/100] train loss [0.8049] validation loss [3.5082] elapsed time [6.42 min]
#
# epoch [62/100] iter [000/016] loss [0.8163] elapsed time [6.43min]
# epoch [62/100] train loss [0.8035] validation loss [3.6934] elapsed time [6.52 min]
#
# epoch [63/100] iter [000/016] loss [0.9105] elapsed time [6.53min]
# epoch [63/100] train loss [0.8159] validation loss [3.4879] elapsed time [6.62 min]
#
# epoch [64/100] iter [000/016] loss [0.8803] elapsed time [6.64min]
# epoch [64/100] train loss [0.8068] validation loss [3.6144] elapsed time [6.73 min]
#
# epoch [65/100] iter [000/016] loss [0.7321] elapsed time [6.74min]
# epoch [65/100] train loss [0.7978] validation loss [3.5605] elapsed time [6.83 min]
#
# epoch [66/100] iter [000/016] loss [0.8953] elapsed time [6.84min]
# epoch [66/100] train loss [0.8052] validation loss [3.5473] elapsed time [6.93 min]
#
# epoch [67/100] iter [000/016] loss [0.9127] elapsed time [6.94min]
# epoch [67/100] train loss [0.7941] validation loss [3.5316] elapsed time [7.03 min]
#
# epoch [68/100] iter [000/016] loss [0.7999] elapsed time [7.04min]
# epoch [68/100] train loss [0.8073] validation loss [3.5919] elapsed time [7.13 min]
#
# epoch [69/100] iter [000/016] loss [0.8406] elapsed time [7.14min]
# epoch [69/100] train loss [0.8049] validation loss [3.4852] elapsed time [7.24 min]
#
# epoch [70/100] iter [000/016] loss [0.7251] elapsed time [7.25min]
# epoch [70/100] train loss [0.8078] validation loss [3.5717] elapsed time [7.34 min]
#
# epoch [71/100] iter [000/016] loss [0.7914] elapsed time [7.35min]
# epoch [71/100] train loss [0.7985] validation loss [3.4679] elapsed time [7.44 min]
#
# epoch [72/100] iter [000/016] loss [0.8441] elapsed time [7.45min]
# epoch [72/100] train loss [0.8007] validation loss [3.5069] elapsed time [7.54 min]
#
# epoch [73/100] iter [000/016] loss [0.7934] elapsed time [7.55min]
# epoch [73/100] train loss [0.7937] validation loss [3.5116] elapsed time [7.64 min]
#
# epoch [74/100] iter [000/016] loss [0.8729] elapsed time [7.65min]
# epoch [74/100] train loss [0.7986] validation loss [3.5955] elapsed time [7.74 min]
#
# epoch [75/100] iter [000/016] loss [0.8660] elapsed time [7.75min]
# epoch [75/100] train loss [0.8105] validation loss [3.4454] elapsed time [7.84 min]
#
# epoch [76/100] iter [000/016] loss [0.7628] elapsed time [7.85min]
# epoch [76/100] train loss [0.8086] validation loss [3.5447] elapsed time [7.94 min]
#
# epoch [77/100] iter [000/016] loss [0.8032] elapsed time [7.95min]
# epoch [77/100] train loss [0.8128] validation loss [3.4873] elapsed time [8.04 min]
#
# epoch [78/100] iter [000/016] loss [0.8046] elapsed time [8.06min]
# epoch [78/100] train loss [0.8045] validation loss [3.4454] elapsed time [8.15 min]
#
# epoch [79/100] iter [000/016] loss [0.8635] elapsed time [8.16min]
# epoch [79/100] train loss [0.8009] validation loss [3.4705] elapsed time [8.25 min]
#
# epoch [80/100] iter [000/016] loss [0.8367] elapsed time [8.26min]
# epoch [80/100] train loss [0.7988] validation loss [3.5353] elapsed time [8.35 min]
#
# epoch [81/100] iter [000/016] loss [0.7499] elapsed time [8.36min]
# epoch [81/100] train loss [0.8035] validation loss [3.4565] elapsed time [8.45 min]
#
# epoch [82/100] iter [000/016] loss [0.8429] elapsed time [8.46min]
# epoch [82/100] train loss [0.7988] validation loss [3.5078] elapsed time [8.55 min]
#
# epoch [83/100] iter [000/016] loss [0.7787] elapsed time [8.56min]
# epoch [83/100] train loss [0.8071] validation loss [3.4760] elapsed time [8.65 min]
#
# epoch [84/100] iter [000/016] loss [0.7321] elapsed time [8.66min]
# epoch [84/100] train loss [0.8150] validation loss [3.5371] elapsed time [8.76 min]
#
# epoch [85/100] iter [000/016] loss [0.8360] elapsed time [8.77min]
# epoch [85/100] train loss [0.8091] validation loss [3.5376] elapsed time [8.86 min]
#
# epoch [86/100] iter [000/016] loss [0.7559] elapsed time [8.87min]
# epoch [86/100] train loss [0.8073] validation loss [3.4897] elapsed time [8.96 min]
#
# epoch [87/100] iter [000/016] loss [0.8313] elapsed time [8.97min]
# epoch [87/100] train loss [0.8005] validation loss [3.4657] elapsed time [9.06 min]
#
# epoch [88/100] iter [000/016] loss [0.8302] elapsed time [9.07min]
# epoch [88/100] train loss [0.8074] validation loss [3.4624] elapsed time [9.16 min]
#
# epoch [89/100] iter [000/016] loss [0.8107] elapsed time [9.17min]
# epoch [89/100] train loss [0.7984] validation loss [3.4659] elapsed time [9.26 min]
#
# epoch [90/100] iter [000/016] loss [0.8474] elapsed time [9.27min]
# epoch [90/100] train loss [0.8005] validation loss [3.4655] elapsed time [9.36 min]
#
# epoch [91/100] iter [000/016] loss [0.7769] elapsed time [9.37min]
# epoch [91/100] train loss [0.7923] validation loss [3.4736] elapsed time [9.46 min]
#
# epoch [92/100] iter [000/016] loss [0.7662] elapsed time [9.47min]
# epoch [92/100] train loss [0.8092] validation loss [3.4114] elapsed time [9.56 min]
#
# epoch [93/100] iter [000/016] loss [0.7768] elapsed time [9.57min]
# epoch [93/100] train loss [0.7985] validation loss [3.4847] elapsed time [9.67 min]
#
# epoch [94/100] iter [000/016] loss [0.8612] elapsed time [9.68min]
# epoch [94/100] train loss [0.8016] validation loss [3.3856] elapsed time [9.77 min]
#
# epoch [95/100] iter [000/016] loss [0.7921] elapsed time [9.78min]
# epoch [95/100] train loss [0.7957] validation loss [3.4677] elapsed time [9.87 min]
#
# epoch [96/100] iter [000/016] loss [0.8815] elapsed time [9.88min]
# epoch [96/100] train loss [0.8023] validation loss [3.2935] elapsed time [9.97 min]
#
# epoch [97/100] iter [000/016] loss [0.7668] elapsed time [9.98min]
# epoch [97/100] train loss [0.8097] validation loss [3.4470] elapsed time [10.07 min]
#
# epoch [98/100] iter [000/016] loss [0.7617] elapsed time [10.08min]
# epoch [98/100] train loss [0.8029] validation loss [3.4465] elapsed time [10.17 min]
#
# epoch [99/100] iter [000/016] loss [0.8278] elapsed time [10.18min]
# epoch [99/100] train loss [0.7994] validation loss [3.4764] elapsed time [10.27 min]

# %%
plt.figure(figsize=(10,5))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='validation loss')
plt.axvline(best_epoch, color='red') # early stopping 
plt.legend()
plt.show()

# %% [markdown]
# # validation data 에 대한 실제 값과 예측 값을 확인해봅시다.

# %%
# validation 결과를 저장해서 그려봅시다.
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(val_dataloader):
        forecast = model(inputs)
        predictions.append(forecast.data.cpu())
predictions = torch.cat(predictions, dim=0)

# %%
predictions.shape
# Out:
# torch.Size([192, 30, 4])

# %%
def plot_prediction_after_N_days(real,pred,N=5):
    
    pred = pred[:,N,:]
    real = real.iloc[N:]
    real = real.iloc[:len(pred)]
    
    cmap=['red','orange','skyblue','green']
    plt.figure(figsize=(16,5))
    for i, col in enumerate(real.columns):
        plt.plot(real[col], label=col+' Real', c=cmap[i], linestyle='--')
    
    pred_df = pd.DataFrame(pred.data.cpu().numpy())
    pred_df.index = real.index
    pred_df.columns = real.columns
    for i, col in enumerate(real.columns):
        plt.plot(pred_df[col], label=col+' Pred', c=cmap[i])
    plt.legend()
    plt.show()

# %%
validation_real = val_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(validation_real, train_dataset.scaler.unscale(predictions), N=1) # N=5 이면 5일 뒤를 예측한 결과를 plot합니다.

# %% [markdown]
# # Test 데이터에도 적용해봅시다.

# %%
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_dataloader):
        forecast = model(inputs)
        predictions.append(forecast.data.cpu())
predictions = torch.cat(predictions, dim=0)

# %%
test_real = test_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(test_real, train_dataset.scaler.unscale(predictions), N=3)

# %% [markdown]
# # 6. N-BEATS 모델을 사용해봅시다.

# %%
class NBeatsNet(nn.Module):
    def __init__(self,
                 forecast_length=24,
                 backcast_length=96,
                 theta_dim=(2, 8, 3),
                 n_trend=3,
                 n_seasonality=3,
                 n_residual=3,
                 hidden_dim=512,
                 feature_dim=4):
        super(NBeatsNet, self).__init__()        
            
        self.trend_stack = []
        self.seasonality_stack = []
        self.residual_stack = [] #bs =[] 이건했는데 fs=[] 이거 안해줌
        # We can simply call pairplot on our DataFrame for an automatic visual analysis 

        for i in range(n_trend):
            self.trend_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[0], mode='trend', feature_dim=feature_dim))    

        for i in range(n_seasonality):
            self.seasonality_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[1], mode='seasonality', feature_dim=feature_dim))
        
        for i in range(n_residual):
            self.residual_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[2], mode='residual', feature_dim=feature_dim))
        # We can simply call pairplot on our DataFrame for an automatic visual analysis 

        
        self.trend_stack = nn.ModuleList(self.trend_stack)
        self.seasonality_stack = nn.ModuleList(self.seasonality_stack)
        self.residual_stack = nn.ModuleList(self.residual_stack)

    def forward(self, backcast):# We can simply call pairplot on our DataFrame for an automatic visual analysis 
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        backcast_stack = []
        forecast_stack = []

        for layer in self.trend_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b

        for layer in self.seasonality_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b


        for layer in self.residual_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b

        backcast = torch.stack(backcast_stack, 0)
        forecast = torch.stack(forecast_stack, 0)
        return backcast, forecast


# ours
class Block(nn.Module):
    def __init__(self, backcast_length, forecast_length, hidden_dim, theta_dim, mode, feature_dim):
        super(Block, self).__init__()
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        self.theta_dim = theta_dim
        self.mode = mode

        self.MLP = nn.Sequential(
                nn.Linear(backcast_length * feature_dim, hidden_dim), 
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU()
            ) # univariate??multivariate??

        if mode == 'residual':
            # residual  
            self.theta_b = nn.Linear(hidden_dim, theta_dim * feature_dim)             
            self.theta_f = nn.Linear(hidden_dim, theta_dim * feature_dim)
            self.linear_b = nn.Linear(theta_dim, backcast_length)
            self.linear_f = nn.Linear(theta_dim, forecast_length)
        else:
            # trend, seasonality# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            self.theta = nn.Linear(hidden_dim, theta_dim*feature_dim)


    def forward(self, x):
        shape = x.shape
        # x: (batch size, backcast length, feature_dim)
        t_b = ((torch.arange(start=0, end=self.backcast_length, device=x.device, dtype=torch.float) - self.backcast_length) / 24 ) # (backcast_len,)
        t_f = ((torch.arange(start=0, end=self.forecast_length, device=x.device, dtype=torch.float)) / 24 ) # (forecast_len,)

        # x -> h
        x = self.MLP(x.reshape(x.shape[0], -1)) # (batch, backcast length * feature_dim) -> (batch, theta_dim)
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        # h -> theta -> backcast, forecast
        if self.mode == 'residual':# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            # residual block
            theta_b = self.theta_b(x).reshape(shape[0], shape[2], self.theta_dim)
            theta_f = self.theta_f(x).reshape(shape[0], shape[2], self.theta_dim)
            b = self.linear_b(theta_b).permute(0,2,1) # (batch, backcast length, feature_dim)
            f = self.linear_f(theta_f).permute(0,2,1) # (batch, forecast length, feature_dim)
        else:
            theta_b = self.theta(x).reshape(shape[0], self.theta_dim, shape[2])
            theta_f = theta_b

            if self.mode == 'trend':
                b = self.get_trend(theta_b, t_b)
                f = self.get_trend(theta_f, t_f)
                
            elif self.mode == 'seasonality':
                b = self.get_seasonality(theta_b, t_b)
                f = self.get_seasonality(theta_f, t_f)
        return b, f# We can simply call pairplot on our DataFrame for an automatic visual analysis 


    def get_trend(self, theta, t):
        # theta dim = 0 -> 수평선 (y=a)
        # theta dim = 1 -> 직선 (y=bx)
        # theta dim = 2 -> 이차곡선 (y=cx^2)
        # ...
        T = torch.stack([t ** i for i in range(theta.shape[1])])  # (theta_dim ,sequence length)
        out = torch.einsum('btf,ts->bsf', theta, T)
        return out


    def get_seasonality(self, theta, t):
        s1 = torch.stack([torch.cos(2 * np.pi * (i+1) * t) for i in range(self.theta_dim//2)]).float()  # H/2-1
        s2 = torch.stack([torch.sin(2 * np.pi * (i+1) * t) for i in range(self.theta_dim//2)]).float()
        S = torch.cat([s1, s2])# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        out = torch.einsum('btf,ts->bsf', theta, S)
        return out

# %%
# model hyper parameters
theta_dim=(2, 8, 3)
n_trend=3
n_seasonality=3
n_residual=3
hidden_dim=64


model = NBeatsNet(forecast_length, backcast_length, theta_dim, n_trend, n_seasonality, n_residual, hidden_dim)
# model = model.cuda()

# We can simply call pairplot on our DataFrame for an automatic visual analysis

# %%
learning_rate = 1e-4

criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
num_epoch = 100



import time
train_losses = []
val_losses = []
best_epoch = 0
start_time = time.time()
best_model_state_dict = None
best_val_loss = 10000
for epoch in range(num_epoch):
    train_loss_mean = 0
    val_loss_mean = 0
    
    # train
    model.train()
    for i, (inputs, labels) in enumerate(train_dataloader):
#         inputs = inputs.cuda()
#         labels = labels.cuda()
        
        forecast = model(inputs)
    
        backcast, forecast = model(inputs)
        loss = criterion(backcast.sum(0), inputs) + criterion(forecast.sum(0), labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss_mean += loss.item()
        
        if i % 100 == 0:# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            print('epoch [{}/{}] iter [{:03d}/{:03d}] loss [{:.4f}] elapsed time [{:.2f}min]'.format(epoch, num_epoch, i, len(train_dataloader), loss.item(), (time.time()-start_time)/60))
    
    train_loss_mean = train_loss_mean/len(train_dataloader)
    
    train_losses.append(train_loss_mean)
    
    # validation
    model.eval()
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_dataloader):
#             inputs = inputs.cuda()
#             labels = labels.cuda()

            backcast, forecast = model(inputs)
            loss = criterion(backcast.sum(0), inputs) + criterion(forecast.sum(0), labels)
            val_loss_mean += loss.item()

        val_loss_mean = val_loss_mean/len(val_dataloader)

        print('epoch [{}/{}] train loss [{:.4f}] validation loss [{:.4f}] elapsed time [{:.2f} min]\n'.format(epoch, num_epoch, train_loss_mean, val_loss_mean, (time.time()-start_time)/60))

        if val_loss_mean < best_val_loss:
            best_epoch = epoch
            best_val_loss = val_loss_mean
            best_model_state_dict = model.state_dict()
    val_losses.append(val_loss_mean)
# Out:
# epoch [0/100] iter [000/016] loss [1.9655] elapsed time [0.00min]
# epoch [0/100] train loss [1.8498] validation loss [7.1733] elapsed time [0.02 min]
#
# epoch [1/100] iter [000/016] loss [1.7096] elapsed time [0.02min]
# epoch [1/100] train loss [1.7122] validation loss [6.7373] elapsed time [0.03 min]
#
# epoch [2/100] iter [000/016] loss [1.5799] elapsed time [0.03min]
# epoch [2/100] train loss [1.5740] validation loss [6.0002] elapsed time [0.05 min]
#
# epoch [3/100] iter [000/016] loss [1.4939] elapsed time [0.05min]
# epoch [3/100] train loss [1.3864] validation loss [4.9561] elapsed time [0.06 min]
#
# epoch [4/100] iter [000/016] loss [1.2660] elapsed time [0.06min]
# epoch [4/100] train loss [1.1818] validation loss [3.7564] elapsed time [0.07 min]
#
# epoch [5/100] iter [000/016] loss [1.1042] elapsed time [0.08min]
# epoch [5/100] train loss [0.9717] validation loss [2.7675] elapsed time [0.09 min]
#
# epoch [6/100] iter [000/016] loss [0.8816] elapsed time [0.09min]
# epoch [6/100] train loss [0.8111] validation loss [2.0547] elapsed time [0.10 min]
#
# epoch [7/100] iter [000/016] loss [0.7620] elapsed time [0.11min]
# epoch [7/100] train loss [0.7145] validation loss [1.8366] elapsed time [0.12 min]
#
# epoch [8/100] iter [000/016] loss [0.6800] elapsed time [0.12min]
# epoch [8/100] train loss [0.6524] validation loss [1.9052] elapsed time [0.13 min]
#
# epoch [9/100] iter [000/016] loss [0.6250] elapsed time [0.14min]
# epoch [9/100] train loss [0.6044] validation loss [1.9112] elapsed time [0.15 min]
#
# epoch [10/100] iter [000/016] loss [0.5836] elapsed time [0.15min]
# epoch [10/100] train loss [0.5650] validation loss [1.8395] elapsed time [0.16 min]
#
# epoch [11/100] iter [000/016] loss [0.5427] elapsed time [0.17min]
# epoch [11/100] train loss [0.5330] validation loss [1.8095] elapsed time [0.18 min]
#
# epoch [12/100] iter [000/016] loss [0.5203] elapsed time [0.18min]
# epoch [12/100] train loss [0.5045] validation loss [1.7541] elapsed time [0.19 min]
#
# epoch [13/100] iter [000/016] loss [0.4945] elapsed time [0.20min]
# epoch [13/100] train loss [0.4798] validation loss [1.7432] elapsed time [0.21 min]
#
# epoch [14/100] iter [000/016] loss [0.4637] elapsed time [0.21min]
# epoch [14/100] train loss [0.4551] validation loss [1.7037] elapsed time [0.22 min]
#
# epoch [15/100] iter [000/016] loss [0.4402] elapsed time [0.23min]
# epoch [15/100] train loss [0.4334] validation loss [1.6850] elapsed time [0.24 min]
#
# epoch [16/100] iter [000/016] loss [0.4164] elapsed time [0.24min]
# epoch [16/100] train loss [0.4116] validation loss [1.6392] elapsed time [0.25 min]
#
# epoch [17/100] iter [000/016] loss [0.3976] elapsed time [0.26min]
# epoch [17/100] train loss [0.3915] validation loss [1.6313] elapsed time [0.27 min]
#
# epoch [18/100] iter [000/016] loss [0.3818] elapsed time [0.27min]
# epoch [18/100] train loss [0.3760] validation loss [1.5988] elapsed time [0.28 min]
#
# epoch [19/100] iter [000/016] loss [0.3682] elapsed time [0.29min]
# epoch [19/100] train loss [0.3579] validation loss [1.5846] elapsed time [0.30 min]
#
# epoch [20/100] iter [000/016] loss [0.3537] elapsed time [0.30min]
# epoch [20/100] train loss [0.3415] validation loss [1.5754] elapsed time [0.31 min]
#
# epoch [21/100] iter [000/016] loss [0.3380] elapsed time [0.32min]
# epoch [21/100] train loss [0.3273] validation loss [1.5338] elapsed time [0.33 min]
#
# epoch [22/100] iter [000/016] loss [0.3145] elapsed time [0.33min]
# epoch [22/100] train loss [0.3117] validation loss [1.5181] elapsed time [0.35 min]
#
# epoch [23/100] iter [000/016] loss [0.3090] elapsed time [0.35min]
# epoch [23/100] train loss [0.2983] validation loss [1.4994] elapsed time [0.36 min]
#
# epoch [24/100] iter [000/016] loss [0.2905] elapsed time [0.36min]
# epoch [24/100] train loss [0.2872] validation loss [1.5002] elapsed time [0.38 min]
#
# epoch [25/100] iter [000/016] loss [0.2779] elapsed time [0.38min]
# epoch [25/100] train loss [0.2745] validation loss [1.4600] elapsed time [0.39 min]
#
# epoch [26/100] iter [000/016] loss [0.2789] elapsed time [0.39min]
# epoch [26/100] train loss [0.2614] validation loss [1.4658] elapsed time [0.41 min]
#
# epoch [27/100] iter [000/016] loss [0.2588] elapsed time [0.41min]
# epoch [27/100] train loss [0.2501] validation loss [1.4565] elapsed time [0.42 min]
#
# epoch [28/100] iter [000/016] loss [0.2415] elapsed time [0.42min]
# epoch [28/100] train loss [0.2393] validation loss [1.4187] elapsed time [0.44 min]
#
# epoch [29/100] iter [000/016] loss [0.2323] elapsed time [0.44min]
# epoch [29/100] train loss [0.2284] validation loss [1.3927] elapsed time [0.45 min]
#
# epoch [30/100] iter [000/016] loss [0.2224] elapsed time [0.45min]
# epoch [30/100] train loss [0.2178] validation loss [1.3704] elapsed time [0.47 min]
#
# epoch [31/100] iter [000/016] loss [0.2115] elapsed time [0.47min]
# epoch [31/100] train loss [0.2080] validation loss [1.3603] elapsed time [0.48 min]
#
# epoch [32/100] iter [000/016] loss [0.1975] elapsed time [0.48min]
# epoch [32/100] train loss [0.1994] validation loss [1.3531] elapsed time [0.50 min]
#
# epoch [33/100] iter [000/016] loss [0.1974] elapsed time [0.50min]
# epoch [33/100] train loss [0.1918] validation loss [1.2984] elapsed time [0.51 min]
#
# epoch [34/100] iter [000/016] loss [0.1789] elapsed time [0.51min]
# epoch [34/100] train loss [0.1832] validation loss [1.2758] elapsed time [0.52 min]
#
# epoch [35/100] iter [000/016] loss [0.1666] elapsed time [0.53min]
# epoch [35/100] train loss [0.1747] validation loss [1.2192] elapsed time [0.54 min]
#
# epoch [36/100] iter [000/016] loss [0.1724] elapsed time [0.54min]
# epoch [36/100] train loss [0.1683] validation loss [1.2161] elapsed time [0.55 min]
#
# epoch [37/100] iter [000/016] loss [0.1558] elapsed time [0.56min]
# epoch [37/100] train loss [0.1605] validation loss [1.2011] elapsed time [0.57 min]
#
# epoch [38/100] iter [000/016] loss [0.1465] elapsed time [0.57min]
# epoch [38/100] train loss [0.1542] validation loss [1.1746] elapsed time [0.58 min]
#
# epoch [39/100] iter [000/016] loss [0.1485] elapsed time [0.59min]
# epoch [39/100] train loss [0.1488] validation loss [1.1866] elapsed time [0.60 min]
#
# epoch [40/100] iter [000/016] loss [0.1503] elapsed time [0.60min]
# epoch [40/100] train loss [0.1432] validation loss [1.1910] elapsed time [0.62 min]
#
# epoch [41/100] iter [000/016] loss [0.1366] elapsed time [0.62min]
# epoch [41/100] train loss [0.1367] validation loss [1.1935] elapsed time [0.63 min]
#
# epoch [42/100] iter [000/016] loss [0.1387] elapsed time [0.63min]
# epoch [42/100] train loss [0.1319] validation loss [1.2076] elapsed time [0.65 min]
#
# epoch [43/100] iter [000/016] loss [0.1253] elapsed time [0.65min]
# epoch [43/100] train loss [0.1285] validation loss [1.1865] elapsed time [0.66 min]
#
# epoch [44/100] iter [000/016] loss [0.1260] elapsed time [0.66min]
# epoch [44/100] train loss [0.1255] validation loss [1.2074] elapsed time [0.68 min]
#
# epoch [45/100] iter [000/016] loss [0.1190] elapsed time [0.68min]
# epoch [45/100] train loss [0.1215] validation loss [1.1973] elapsed time [0.69 min]
#
# epoch [46/100] iter [000/016] loss [0.1215] elapsed time [0.69min]
# epoch [46/100] train loss [0.1187] validation loss [1.1803] elapsed time [0.71 min]
#
# epoch [47/100] iter [000/016] loss [0.1159] elapsed time [0.71min]
# epoch [47/100] train loss [0.1162] validation loss [1.1820] elapsed time [0.72 min]
#
# epoch [48/100] iter [000/016] loss [0.1184] elapsed time [0.72min]
# epoch [48/100] train loss [0.1143] validation loss [1.1999] elapsed time [0.74 min]
#
# epoch [49/100] iter [000/016] loss [0.1112] elapsed time [0.74min]
# epoch [49/100] train loss [0.1139] validation loss [1.2195] elapsed time [0.75 min]
#
# epoch [50/100] iter [000/016] loss [0.1173] elapsed time [0.75min]
# epoch [50/100] train loss [0.1121] validation loss [1.2053] elapsed time [0.77 min]
#
# epoch [51/100] iter [000/016] loss [0.1155] elapsed time [0.77min]
# epoch [51/100] train loss [0.1116] validation loss [1.2567] elapsed time [0.78 min]
#
# epoch [52/100] iter [000/016] loss [0.1074] elapsed time [0.79min]
# epoch [52/100] train loss [0.1103] validation loss [1.2029] elapsed time [0.80 min]
#
# epoch [53/100] iter [000/016] loss [0.1075] elapsed time [0.80min]
# epoch [53/100] train loss [0.1110] validation loss [1.2098] elapsed time [0.81 min]
#
# epoch [54/100] iter [000/016] loss [0.1071] elapsed time [0.82min]
# epoch [54/100] train loss [0.1093] validation loss [1.2082] elapsed time [0.83 min]
#
# epoch [55/100] iter [000/016] loss [0.1062] elapsed time [0.83min]
# epoch [55/100] train loss [0.1093] validation loss [1.2147] elapsed time [0.85 min]
#
# epoch [56/100] iter [000/016] loss [0.1117] elapsed time [0.85min]
# epoch [56/100] train loss [0.1083] validation loss [1.2309] elapsed time [0.86 min]
#
# epoch [57/100] iter [000/016] loss [0.1110] elapsed time [0.86min]
# epoch [57/100] train loss [0.1080] validation loss [1.2554] elapsed time [0.88 min]
#
# epoch [58/100] iter [000/016] loss [0.1188] elapsed time [0.88min]
# epoch [58/100] train loss [0.1084] validation loss [1.2273] elapsed time [0.89 min]
#
# epoch [59/100] iter [000/016] loss [0.1139] elapsed time [0.89min]
# epoch [59/100] train loss [0.1071] validation loss [1.2538] elapsed time [0.91 min]
#
# epoch [60/100] iter [000/016] loss [0.1127] elapsed time [0.91min]
# epoch [60/100] train loss [0.1056] validation loss [1.2179] elapsed time [0.92 min]
#
# epoch [61/100] iter [000/016] loss [0.0964] elapsed time [0.93min]
# epoch [61/100] train loss [0.1054] validation loss [1.2406] elapsed time [0.94 min]
#
# epoch [62/100] iter [000/016] loss [0.0978] elapsed time [0.94min]
# epoch [62/100] train loss [0.1048] validation loss [1.2148] elapsed time [0.95 min]
#
# epoch [63/100] iter [000/016] loss [0.1053] elapsed time [0.96min]
# epoch [63/100] train loss [0.1045] validation loss [1.2081] elapsed time [0.97 min]
#
# epoch [64/100] iter [000/016] loss [0.1059] elapsed time [0.97min]
# epoch [64/100] train loss [0.1046] validation loss [1.2085] elapsed time [0.98 min]
#
# epoch [65/100] iter [000/016] loss [0.1054] elapsed time [0.99min]
# epoch [65/100] train loss [0.1039] validation loss [1.2214] elapsed time [1.00 min]
#
# epoch [66/100] iter [000/016] loss [0.0997] elapsed time [1.00min]
# epoch [66/100] train loss [0.1044] validation loss [1.2312] elapsed time [1.02 min]
#
# epoch [67/100] iter [000/016] loss [0.0951] elapsed time [1.02min]
# epoch [67/100] train loss [0.1030] validation loss [1.2407] elapsed time [1.03 min]
#
# epoch [68/100] iter [000/016] loss [0.1086] elapsed time [1.03min]
# epoch [68/100] train loss [0.1033] validation loss [1.2102] elapsed time [1.05 min]
#
# epoch [69/100] iter [000/016] loss [0.0979] elapsed time [1.05min]
# epoch [69/100] train loss [0.1022] validation loss [1.2066] elapsed time [1.06 min]
#
# epoch [70/100] iter [000/016] loss [0.1088] elapsed time [1.07min]
# epoch [70/100] train loss [0.1018] validation loss [1.2117] elapsed time [1.08 min]
#
# epoch [71/100] iter [000/016] loss [0.0942] elapsed time [1.08min]
# epoch [71/100] train loss [0.1015] validation loss [1.2086] elapsed time [1.09 min]
#
# epoch [72/100] iter [000/016] loss [0.0964] elapsed time [1.10min]
# epoch [72/100] train loss [0.1010] validation loss [1.2234] elapsed time [1.11 min]
#
# epoch [73/100] iter [000/016] loss [0.1021] elapsed time [1.11min]
# epoch [73/100] train loss [0.1011] validation loss [1.2151] elapsed time [1.12 min]
#
# epoch [74/100] iter [000/016] loss [0.0901] elapsed time [1.13min]
# epoch [74/100] train loss [0.1004] validation loss [1.2020] elapsed time [1.14 min]
#
# epoch [75/100] iter [000/016] loss [0.0967] elapsed time [1.14min]
# epoch [75/100] train loss [0.1000] validation loss [1.2215] elapsed time [1.15 min]
#
# epoch [76/100] iter [000/016] loss [0.0939] elapsed time [1.16min]
# epoch [76/100] train loss [0.1004] validation loss [1.2209] elapsed time [1.17 min]
#
# epoch [77/100] iter [000/016] loss [0.0992] elapsed time [1.17min]
# epoch [77/100] train loss [0.0994] validation loss [1.2235] elapsed time [1.18 min]
#
# epoch [78/100] iter [000/016] loss [0.1021] elapsed time [1.19min]
# epoch [78/100] train loss [0.0990] validation loss [1.2161] elapsed time [1.20 min]
#
# epoch [79/100] iter [000/016] loss [0.0997] elapsed time [1.20min]
# epoch [79/100] train loss [0.0986] validation loss [1.2108] elapsed time [1.22 min]
#
# epoch [80/100] iter [000/016] loss [0.0970] elapsed time [1.22min]
# epoch [80/100] train loss [0.0981] validation loss [1.2014] elapsed time [1.23 min]
#
# epoch [81/100] iter [000/016] loss [0.0946] elapsed time [1.23min]
# epoch [81/100] train loss [0.0974] validation loss [1.2383] elapsed time [1.25 min]
#
# epoch [82/100] iter [000/016] loss [0.0900] elapsed time [1.25min]
# epoch [82/100] train loss [0.0973] validation loss [1.2076] elapsed time [1.26 min]
#
# epoch [83/100] iter [000/016] loss [0.0944] elapsed time [1.27min]
# epoch [83/100] train loss [0.0975] validation loss [1.2034] elapsed time [1.28 min]
#
# epoch [84/100] iter [000/016] loss [0.0957] elapsed time [1.28min]
# epoch [84/100] train loss [0.0974] validation loss [1.2407] elapsed time [1.29 min]
#
# epoch [85/100] iter [000/016] loss [0.0946] elapsed time [1.30min]
# epoch [85/100] train loss [0.0976] validation loss [1.2398] elapsed time [1.31 min]
#
# epoch [86/100] iter [000/016] loss [0.0998] elapsed time [1.31min]
# epoch [86/100] train loss [0.0969] validation loss [1.2004] elapsed time [1.32 min]
#
# epoch [87/100] iter [000/016] loss [0.0964] elapsed time [1.33min]
# epoch [87/100] train loss [0.0967] validation loss [1.2218] elapsed time [1.34 min]
#
# epoch [88/100] iter [000/016] loss [0.0933] elapsed time [1.34min]
# epoch [88/100] train loss [0.0966] validation loss [1.1864] elapsed time [1.36 min]
#
# epoch [89/100] iter [000/016] loss [0.0942] elapsed time [1.36min]
# epoch [89/100] train loss [0.0964] validation loss [1.2071] elapsed time [1.37 min]
#
# epoch [90/100] iter [000/016] loss [0.0931] elapsed time [1.37min]
# epoch [90/100] train loss [0.0958] validation loss [1.1973] elapsed time [1.39 min]
#
# epoch [91/100] iter [000/016] loss [0.0970] elapsed time [1.39min]
# epoch [91/100] train loss [0.0954] validation loss [1.2202] elapsed time [1.40 min]
#
# epoch [92/100] iter [000/016] loss [0.0980] elapsed time [1.40min]
# epoch [92/100] train loss [0.0953] validation loss [1.1676] elapsed time [1.42 min]
#
# epoch [93/100] iter [000/016] loss [0.1002] elapsed time [1.42min]
# epoch [93/100] train loss [0.0947] validation loss [1.2264] elapsed time [1.43 min]
#
# epoch [94/100] iter [000/016] loss [0.0953] elapsed time [1.44min]
# epoch [94/100] train loss [0.0943] validation loss [1.1903] elapsed time [1.45 min]
#
# epoch [95/100] iter [000/016] loss [0.0963] elapsed time [1.45min]
# epoch [95/100] train loss [0.0947] validation loss [1.2076] elapsed time [1.46 min]
#
# epoch [96/100] iter [000/016] loss [0.0921] elapsed time [1.47min]
# epoch [96/100] train loss [0.0944] validation loss [1.1782] elapsed time [1.48 min]
#
# epoch [97/100] iter [000/016] loss [0.0953] elapsed time [1.48min]
# epoch [97/100] train loss [0.0942] validation loss [1.1864] elapsed time [1.49 min]
#
# epoch [98/100] iter [000/016] loss [0.1012] elapsed time [1.50min]
# epoch [98/100] train loss [0.0936] validation loss [1.2139] elapsed time [1.51 min]
#
# epoch [99/100] iter [000/016] loss [0.0940] elapsed time [1.51min]
# epoch [99/100] train loss [0.0933] validation loss [1.1804] elapsed time [1.52 min]

# %%
plt.figure(figsize=(10,5))
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='validation loss')
plt.axvline(best_epoch, color='red') # early stopping 
plt.legend()
plt.show()

# %%
# validation 결과를 저장해서 그려봅시다.
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(val_dataloader):
        backcast, forecast = model(inputs)
        predictions.append(forecast.sum(0).data.cpu())
predictions = torch.cat(predictions, dim=0)

validation_real = val_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(validation_real, train_dataset.scaler.unscale(predictions), N=1) # N=5 이면 5일 뒤를 예측한 결과를 plot합니다.

# %%
# test 결과를 저장해서 그려봅시다.
predictions = []
with torch.no_grad():
    for i, (inputs, labels) in enumerate(test_dataloader):
        backcast, forecast = model(inputs)
        predictions.append(forecast.sum(0).data.cpu())
predictions = torch.cat(predictions, dim=0)

test_real = test_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
plot_prediction_after_N_days(test_real, train_dataset.scaler.unscale(predictions), N=3)# We can simply call pairplot on our DataFrame for an automatic visual analysis
