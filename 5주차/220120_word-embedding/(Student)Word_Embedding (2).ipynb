# %%
# To ignore deprecated warnings
import os
import warnings
warnings.simplefilter("ignore")
warnings.warn("deprecated", DeprecationWarning)
import os
import random
import numpy as np
from gensim.models import word2vec #  word2vec 관련 모델을 제공해주는 library  
import nltk
from nltk.corpus import movie_reviews # corpus 를 가져오는 용도 
from sklearn.manifold import TSNE # 시각화를 위한 TSNE 사용 
from sklearn.metrics import accuracy_score # accuracy score 를 계산하기 위한 metric 라이브러리 불러오기 
import matplotlib as mpl
import matplotlib.pyplot as plt
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

from torch.utils import data # pytorch data class 
import torch.nn as nn # pytorch neural network 불러오기 
import torch.nn.utils.rnn as rnn_utils # rnn utils
import torch

import pickle

# os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Chapter 1

# %% [markdown]
# # Word embedding (CBOW & Skip-Gram)

# %% [markdown]
# ![대체 텍스트](./figures/embedding.png)

# %% [markdown]
# ![대체 텍스트](./figures/w2vec_1.png)

# %%
# 파라메터값 지정
num_features = 300 # 임베딩 벡터 사이즈
negative = 10 # negative sampling할 단어 수
min_word_count = 10 # 한 문장에 대한 최소 문자 수
window = 5 # context window 사이즈
downsampling = 0.75 # 단어의 빈도수가 높은 단어에 대해 빈도수를 낮춤
epoch = 5 # epoch 수

# %%
# preparing data
data_path = '/content/drive/MyDrive/실습1'
sentences = []
pos_data = open(os.path.join(data_path, "lm_data/pos/train.txt")).readlines()
neg_data = open(os.path.join(data_path, "lm_data/neg/train.txt")).readlines()
data_ = pos_data + neg_data
for line in data_:
    sentences.append(line.strip().split(' '))

print(len(sentences))
# Out:
# 62966

# %%
# skip-gram 모델 학습
skip_gram = word2vec.Word2Vec(sentences,
                              sg = 1, # skip-gram
                              negative=negative,
                              size=num_features, 
                              min_count=min_word_count,
                              window=window,
                              sample=downsampling,
                              iter=epoch)

# CBOW 모델 학습
CBOW = word2vec.Word2Vec(sentences,
                              sg = 0, # CBOW
                              negative=negative,
                              size=num_features, 
                              min_count=min_word_count,
                              window=window,
                              sample=downsampling,
                              iter=epoch)
# Out:
# 2022-01-20 05:20:06,291 : INFO : collecting all words and their counts
# 2022-01-20 05:20:06,292 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 05:20:06,346 : INFO : PROGRESS: at sentence #10000, processed 239982 words, keeping 20149 word types
# 2022-01-20 05:20:06,398 : INFO : PROGRESS: at sentence #20000, processed 475267 words, keeping 28557 word types
# 2022-01-20 05:20:06,448 : INFO : PROGRESS: at sentence #30000, processed 718530 words, keeping 35153 word types
# 2022-01-20 05:20:06,494 : INFO : PROGRESS: at sentence #40000, processed 942659 words, keeping 40650 word types
# 2022-01-20 05:20:06,544 : INFO : PROGRESS: at sentence #50000, processed 1164181 words, keeping 45109 word types
# 2022-01-20 05:20:06,590 : INFO : PROGRESS: at sentence #60000, processed 1387734 words, keeping 49141 word types
# 2022-01-20 05:20:06,606 : INFO : collected 50290 word types from a corpus of 1453943 raw words and 62966 sentences
# 2022-01-20 05:20:06,606 : INFO : Loading a fresh vocabulary
# 2022-01-20 05:20:06,780 : INFO : effective_min_count=10 retains 9220 unique words (18% of original 50290, drops 41070)
# 2022-01-20 05:20:06,781 : INFO : effective_min_count=10 leaves 1358527 word corpus (93% of original 1453943, drops 95416)
# 2022-01-20 05:20:06,808 : INFO : deleting the raw counts dictionary of 50290 items
# 2022-01-20 05:20:06,810 : INFO : sample=0.75 downsamples 0 most-common words
# 2022-01-20 05:20:06,812 : INFO : downsampling leaves estimated 1358527 word corpus (100.0% of prior 1358527)
# 2022-01-20 05:20:06,835 : INFO : estimated required memory for 9220 words and 300 dimensions: 26738000 bytes
# 2022-01-20 05:20:06,836 : INFO : resetting layer weights
# 2022-01-20 05:20:08,729 : INFO : training model with 3 workers on 9220 vocabulary and 300 features, using sg=1 hs=0 sample=0.75 negative=10 window=5
# 2022-01-20 05:20:09,741 : INFO : EPOCH 1 - PROGRESS: at 5.49% examples, 74228 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:10,903 : INFO : EPOCH 1 - PROGRESS: at 11.92% examples, 77256 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:12,026 : INFO : EPOCH 1 - PROGRESS: at 18.74% examples, 79269 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:13,063 : INFO : EPOCH 1 - PROGRESS: at 25.00% examples, 79770 words/s, in_qsize 6, out_qsize 0
# 2022-01-20 05:20:14,285 : INFO : EPOCH 1 - PROGRESS: at 31.36% examples, 78978 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:15,312 : INFO : EPOCH 1 - PROGRESS: at 37.83% examples, 80838 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:16,408 : INFO : EPOCH 1 - PROGRESS: at 44.47% examples, 81418 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:17,540 : INFO : EPOCH 1 - PROGRESS: at 50.95% examples, 81530 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:18,560 : INFO : EPOCH 1 - PROGRESS: at 57.39% examples, 81625 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:19,592 : INFO : EPOCH 1 - PROGRESS: at 63.99% examples, 81605 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:20,746 : INFO : EPOCH 1 - PROGRESS: at 70.49% examples, 80809 words/s, in_qsize 6, out_qsize 0
# 2022-01-20 05:20:21,789 : INFO : EPOCH 1 - PROGRESS: at 76.95% examples, 80773 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:22,791 : INFO : EPOCH 1 - PROGRESS: at 83.37% examples, 80975 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:23,833 : INFO : EPOCH 1 - PROGRESS: at 91.09% examples, 82205 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:24,877 : INFO : EPOCH 1 - PROGRESS: at 96.72% examples, 81511 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:25,172 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:20:25,222 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:20:25,235 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:20:25,236 : INFO : EPOCH - 1 : training on 1453943 raw words (1358527 effective words) took 16.5s, 82336 effective words/s
# 2022-01-20 05:20:26,295 : INFO : EPOCH 2 - PROGRESS: at 5.49% examples, 70882 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:27,351 : INFO : EPOCH 2 - PROGRESS: at 11.28% examples, 75016 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:28,403 : INFO : EPOCH 2 - PROGRESS: at 18.00% examples, 79549 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:29,506 : INFO : EPOCH 2 - PROGRESS: at 24.33% examples, 78766 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:30,577 : INFO : EPOCH 2 - PROGRESS: at 30.07% examples, 78690 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:31,676 : INFO : EPOCH 2 - PROGRESS: at 37.22% examples, 81187 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:32,860 : INFO : EPOCH 2 - PROGRESS: at 43.81% examples, 80774 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:33,955 : INFO : EPOCH 2 - PROGRESS: at 50.25% examples, 81326 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:34,958 : INFO : EPOCH 2 - PROGRESS: at 56.66% examples, 81564 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:36,137 : INFO : EPOCH 2 - PROGRESS: at 63.98% examples, 81322 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:37,156 : INFO : EPOCH 2 - PROGRESS: at 71.17% examples, 82253 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:38,277 : INFO : EPOCH 2 - PROGRESS: at 78.38% examples, 82320 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:39,369 : INFO : EPOCH 2 - PROGRESS: at 85.53% examples, 82562 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:40,391 : INFO : EPOCH 2 - PROGRESS: at 92.42% examples, 83161 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:41,454 : INFO : EPOCH 2 - PROGRESS: at 98.89% examples, 82889 words/s, in_qsize 2, out_qsize 1
# 2022-01-20 05:20:41,461 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:20:41,495 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:20:41,519 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:20:41,520 : INFO : EPOCH - 2 : training on 1453943 raw words (1358527 effective words) took 16.3s, 83467 effective words/s
# 2022-01-20 05:20:42,537 : INFO : EPOCH 3 - PROGRESS: at 5.49% examples, 73845 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:43,562 : INFO : EPOCH 3 - PROGRESS: at 11.27% examples, 77790 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:44,683 : INFO : EPOCH 3 - PROGRESS: at 18.00% examples, 79660 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:45,853 : INFO : EPOCH 3 - PROGRESS: at 25.00% examples, 79797 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:46,857 : INFO : EPOCH 3 - PROGRESS: at 30.69% examples, 80490 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:47,893 : INFO : EPOCH 3 - PROGRESS: at 37.22% examples, 82035 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:48,914 : INFO : EPOCH 3 - PROGRESS: at 42.53% examples, 80786 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:49,961 : INFO : EPOCH 3 - PROGRESS: at 49.00% examples, 81796 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:51,126 : INFO : EPOCH 3 - PROGRESS: at 55.99% examples, 81563 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:52,212 : INFO : EPOCH 3 - PROGRESS: at 63.29% examples, 82036 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:53,390 : INFO : EPOCH 3 - PROGRESS: at 71.17% examples, 82597 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:54,394 : INFO : EPOCH 3 - PROGRESS: at 77.68% examples, 82665 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:55,404 : INFO : EPOCH 3 - PROGRESS: at 83.27% examples, 82017 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:56,657 : INFO : EPOCH 3 - PROGRESS: at 91.08% examples, 82010 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:20:57,722 : INFO : EPOCH 3 - PROGRESS: at 98.08% examples, 82393 words/s, in_qsize 3, out_qsize 0
# 2022-01-20 05:20:57,851 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:20:57,875 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:20:57,892 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:20:57,893 : INFO : EPOCH - 3 : training on 1453943 raw words (1358527 effective words) took 16.4s, 83013 effective words/s
# 2022-01-20 05:20:59,069 : INFO : EPOCH 4 - PROGRESS: at 6.16% examples, 71919 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:00,087 : INFO : EPOCH 4 - PROGRESS: at 12.60% examples, 80817 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:01,130 : INFO : EPOCH 4 - PROGRESS: at 19.42% examples, 83647 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:02,184 : INFO : EPOCH 4 - PROGRESS: at 25.70% examples, 82800 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:03,208 : INFO : EPOCH 4 - PROGRESS: at 32.04% examples, 84326 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:04,312 : INFO : EPOCH 4 - PROGRESS: at 37.83% examples, 82922 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:05,467 : INFO : EPOCH 4 - PROGRESS: at 44.53% examples, 82553 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:06,484 : INFO : EPOCH 4 - PROGRESS: at 50.95% examples, 83630 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:07,569 : INFO : EPOCH 4 - PROGRESS: at 58.06% examples, 83901 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:08,705 : INFO : EPOCH 4 - PROGRESS: at 65.44% examples, 83728 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:09,750 : INFO : EPOCH 4 - PROGRESS: at 72.59% examples, 84267 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:10,895 : INFO : EPOCH 4 - PROGRESS: at 80.42% examples, 84716 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:12,104 : INFO : EPOCH 4 - PROGRESS: at 88.32% examples, 84748 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:13,192 : INFO : EPOCH 4 - PROGRESS: at 95.32% examples, 84824 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:13,627 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:21:13,734 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:21:13,760 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:21:13,761 : INFO : EPOCH - 4 : training on 1453943 raw words (1358527 effective words) took 15.9s, 85662 effective words/s
# 2022-01-20 05:21:14,798 : INFO : EPOCH 5 - PROGRESS: at 6.16% examples, 81463 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:16,026 : INFO : EPOCH 5 - PROGRESS: at 12.60% examples, 78223 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:17,130 : INFO : EPOCH 5 - PROGRESS: at 20.13% examples, 83111 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:18,213 : INFO : EPOCH 5 - PROGRESS: at 26.90% examples, 83946 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:19,246 : INFO : EPOCH 5 - PROGRESS: at 33.35% examples, 85088 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:20,378 : INFO : EPOCH 5 - PROGRESS: at 39.88% examples, 84610 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:21,502 : INFO : EPOCH 5 - PROGRESS: at 46.47% examples, 84367 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:22,556 : INFO : EPOCH 5 - PROGRESS: at 53.04% examples, 84837 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:23,557 : INFO : EPOCH 5 - PROGRESS: at 59.62% examples, 84768 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:24,575 : INFO : EPOCH 5 - PROGRESS: at 66.14% examples, 84576 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:25,688 : INFO : EPOCH 5 - PROGRESS: at 73.35% examples, 84526 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:26,689 : INFO : EPOCH 5 - PROGRESS: at 81.09% examples, 85917 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:27,787 : INFO : EPOCH 5 - PROGRESS: at 88.32% examples, 85858 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:28,879 : INFO : EPOCH 5 - PROGRESS: at 95.32% examples, 85832 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:29,284 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:21:29,401 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:21:29,454 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:21:29,455 : INFO : EPOCH - 5 : training on 1453943 raw words (1358527 effective words) took 15.7s, 86602 effective words/s
# 2022-01-20 05:21:29,456 : INFO : training on a 7269715 raw words (6792635 effective words) took 80.7s, 84147 effective words/s
# 2022-01-20 05:21:29,458 : INFO : collecting all words and their counts
# 2022-01-20 05:21:29,459 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 05:21:29,507 : INFO : PROGRESS: at sentence #10000, processed 239982 words, keeping 20149 word types
# 2022-01-20 05:21:29,555 : INFO : PROGRESS: at sentence #20000, processed 475267 words, keeping 28557 word types
# 2022-01-20 05:21:29,604 : INFO : PROGRESS: at sentence #30000, processed 718530 words, keeping 35153 word types
# 2022-01-20 05:21:29,651 : INFO : PROGRESS: at sentence #40000, processed 942659 words, keeping 40650 word types
# 2022-01-20 05:21:29,694 : INFO : PROGRESS: at sentence #50000, processed 1164181 words, keeping 45109 word types
# 2022-01-20 05:21:29,738 : INFO : PROGRESS: at sentence #60000, processed 1387734 words, keeping 49141 word types
# 2022-01-20 05:21:29,754 : INFO : collected 50290 word types from a corpus of 1453943 raw words and 62966 sentences
# 2022-01-20 05:21:29,755 : INFO : Loading a fresh vocabulary
# 2022-01-20 05:21:29,792 : INFO : effective_min_count=10 retains 9220 unique words (18% of original 50290, drops 41070)
# 2022-01-20 05:21:29,793 : INFO : effective_min_count=10 leaves 1358527 word corpus (93% of original 1453943, drops 95416)
# 2022-01-20 05:21:29,816 : INFO : deleting the raw counts dictionary of 50290 items
# 2022-01-20 05:21:29,819 : INFO : sample=0.75 downsamples 0 most-common words
# 2022-01-20 05:21:29,821 : INFO : downsampling leaves estimated 1358527 word corpus (100.0% of prior 1358527)
# 2022-01-20 05:21:29,841 : INFO : estimated required memory for 9220 words and 300 dimensions: 26738000 bytes
# 2022-01-20 05:21:29,848 : INFO : resetting layer weights
# 2022-01-20 05:21:31,674 : INFO : training model with 3 workers on 9220 vocabulary and 300 features, using sg=0 hs=0 sample=0.75 negative=10 window=5
# 2022-01-20 05:21:32,692 : INFO : EPOCH 1 - PROGRESS: at 25.03% examples, 341553 words/s, in_qsize 4, out_qsize 1
# 2022-01-20 05:21:33,705 : INFO : EPOCH 1 - PROGRESS: at 50.27% examples, 350006 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:34,710 : INFO : EPOCH 1 - PROGRESS: at 78.38% examples, 354232 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:35,465 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:21:35,472 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:21:35,475 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:21:35,476 : INFO : EPOCH - 1 : training on 1453943 raw words (1358527 effective words) took 3.8s, 358003 effective words/s
# 2022-01-20 05:21:36,503 : INFO : EPOCH 2 - PROGRESS: at 25.00% examples, 338895 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:37,522 : INFO : EPOCH 2 - PROGRESS: at 50.25% examples, 347709 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:38,548 : INFO : EPOCH 2 - PROGRESS: at 77.68% examples, 347186 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:39,282 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:21:39,321 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:21:39,331 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:21:39,332 : INFO : EPOCH - 2 : training on 1453943 raw words (1358527 effective words) took 3.8s, 353108 effective words/s
# 2022-01-20 05:21:40,341 : INFO : EPOCH 3 - PROGRESS: at 25.00% examples, 344970 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:41,357 : INFO : EPOCH 3 - PROGRESS: at 49.61% examples, 346817 words/s, in_qsize 6, out_qsize 0
# 2022-01-20 05:21:42,359 : INFO : EPOCH 3 - PROGRESS: at 77.68% examples, 352374 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:43,108 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:21:43,141 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:21:43,142 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:21:43,145 : INFO : EPOCH - 3 : training on 1453943 raw words (1358527 effective words) took 3.8s, 357161 effective words/s
# 2022-01-20 05:21:44,158 : INFO : EPOCH 4 - PROGRESS: at 25.70% examples, 352399 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:45,160 : INFO : EPOCH 4 - PROGRESS: at 49.00% examples, 343556 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:46,180 : INFO : EPOCH 4 - PROGRESS: at 77.65% examples, 351289 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:46,965 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:21:46,973 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:21:46,992 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:21:46,993 : INFO : EPOCH - 4 : training on 1453943 raw words (1358527 effective words) took 3.8s, 353709 effective words/s
# 2022-01-20 05:21:48,030 : INFO : EPOCH 5 - PROGRESS: at 25.70% examples, 344666 words/s, in_qsize 6, out_qsize 1
# 2022-01-20 05:21:49,034 : INFO : EPOCH 5 - PROGRESS: at 50.95% examples, 353085 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:50,056 : INFO : EPOCH 5 - PROGRESS: at 79.00% examples, 354300 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 05:21:50,782 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 05:21:50,808 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 05:21:50,812 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 05:21:50,813 : INFO : EPOCH - 5 : training on 1453943 raw words (1358527 effective words) took 3.8s, 356396 effective words/s
# 2022-01-20 05:21:50,815 : INFO : training on a 7269715 raw words (6792635 effective words) took 19.1s, 354936 effective words/s

# %% [markdown]
# ##  Training result

# %%
skip_gram.wv.most_similar("man") # skip-gram 모델을 이용하여 'man'에 가장 유사한 단어 추출
# Out:
# 2022-01-20 05:21:50,822 : INFO : precomputing L2-norms of word weight vectors
# [('boy', 0.7445113658905029),
#  ('woman', 0.7156598567962646),
#  ('doctor', 0.7100571393966675),
#  ('teenager', 0.7061657905578613),
#  ('guy', 0.6973567008972168),
#  ('lady', 0.6946150064468384),
#  ('girl', 0.6898325681686401),
#  ('skinhead', 0.6791943907737732),
#  ('person', 0.6775778532028198),
#  ('prostitute', 0.6742604970932007)]

# %%
CBOW.wv.most_similar("man") # CBOW 모델을 이용하여 'man'에 가장 유사한 단어 추출
# Out:
# 2022-01-20 05:21:50,851 : INFO : precomputing L2-norms of word weight vectors
# [('woman', 0.9398400187492371),
#  ('girl', 0.9112023115158081),
#  ('boy', 0.8750251531600952),
#  ('child', 0.8294999599456787),
#  ('person', 0.7931860685348511),
#  ('kid', 0.7874599695205688),
#  ('doctor', 0.7758957147598267),
#  ('secret', 0.7711079120635986),
#  ('guy', 0.7660730481147766),
#  ('scientist', 0.743147611618042)]

# %%
vector = skip_gram["king"] - skip_gram["man"] + skip_gram["women"]
skip_gram.wv.similar_by_vector(vector, topn=10, restrict_vocab=None)
# Out:
# [('king', 0.6331064701080322),
#  ('politicians', 0.5855693817138672),
#  ('coen', 0.5828657150268555),
#  ('lyrics', 0.5756121873855591),
#  ('leaders', 0.5707928538322449),
#  ('veterans', 0.5701630115509033),
#  ('wives', 0.5674960613250732),
#  ('personalities', 0.5669083595275879),
#  ('sisters', 0.5653091669082642),
#  ('respectively', 0.5635881423950195)]

# %%
def render_TSNE(vocab, word_emb):
    """
    TSNE를 이용한 word2vec 시각화 
    args:
        vocab    - vocab list
        word_emb - word embeddings
    """
    tsne = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32) #TSNE 시각화를 위한 initialization
    _tsne = tsne.fit_transform(word_emb) # TSNE 시각화 적용
    x_coordinate = _tsne[:,0] # x 좌표
    y_coordinate = _tsne[:,1] # y 좌표

    # scatter plot initialization
    fig, ax = plt.subplots()
    fig.set_size_inches(40, 20)
    ax.scatter(x_coordinate, y_coordinate)

    for i, word in enumerate(random_vocab):
        ax.annotate(word,(x_coordinate[i], y_coordinate[i]), fontsize=30) # 각 scatter들에대해 단어 labeling

    plt.show()

# %%
# Skip-gram 시각화(TSNE)
vocab = list(skip_gram.wv.vocab) # vocab list 불러오기
random_vocab = random.sample(vocab,k=100) #100개의 임의 단어를 랜덤 샘플링
word_emb = skip_gram[random_vocab] # 샘플링된 단어에 대해 학습된 임베딩 벡터 불러오기
render_TSNE(random_vocab, word_emb) # TSNE 시각화

# %%
# CBOW 시각화(TSNE)
vocab = list(CBOW.wv.vocab) # vocab list 불러오기
random_vocab = random.sample(vocab,k=100) #100개의 임의 단어를 랜덤 샘플링
word_emb = skip_gram[random_vocab] # 샘플링된 단어에 대해 학습된 임베딩 벡터 불러오기
render_TSNE(random_vocab, word_emb) # TSNE 시각화

# %% [markdown]
# # Chapter2

# %% [markdown]
# # Lanaguage Model (RNN)

# %% [markdown]
# ![대체 텍스트](./figures/lm_1.jpg)

# %%
def build_dict(seqs):
    num_skip_sent = 0
    word_count = 4
    vocab = ["<pad>","<s>","</s>","<unk>"]
    word2id = {"<pad>": 0, "<s>": 1, "</s>": 2, "<unk>": 3}
    id2word = {0: "<pad>", 1: "<s>", 2: "</s>", 3: "<unk>"}
    print("Building vocab and dict..")
    for line in seqs:
        words = line.strip().split(' ') # tokenized by space 
        for word in words:
            if word not in vocab:
                word_count += 1 # increment word_count
                vocab.append(word) # append new unique word
                index = word_count - 1 # word index (consider index 0)
                word2id[word] = index # word to index
                id2word[index] = word # index to word
    
    print("Number of unique words: %d" % len(vocab))
    print("Finised building vocab and dict!")

    return vocab, word2id, id2word

# %%
# Training corpus를 사용하여 vocab과 dict 구성
assert os.path.isfile(os.path.join(data_path, "lm_data/pos/train.txt"))
assert os.path.isfile(os.path.join(data_path, "lm_data/neg/train.txt"))
pos_seqs = open(os.path.join(data_path, "lm_data/pos/train.txt")).readlines()
neg_seqs = open(os.path.join(data_path, "lm_data/neg/train.txt")).readlines()
seqs = pos_seqs + neg_seqs # 긍정 corpus + 부정 corpus

# %%
print(seqs[1])
# Out:
# for starters , it was created by alan moore ( and eddie campbell ) , who brought the medium to a whole new level in the mid '80s with a 12-part series called the watchmen .

# %%
# Building vocab or loading existing vocab
path = os.path.join(data_path, "lm_id2word.pkl")
if os.path.isfile(path):
    with open(os.path.join(data_path, "lm_id2word.pkl"), "rb") as f:
        id2word = pickle.load(f)
    with open(os.path.join(data_path, "lm_word2id.pkl"), "rb") as f:
        word2id = pickle.load(f)
    with open(os.path.join(data_path, "lm_vocab.pkl"), "rb") as f:
        vocab = pickle.load(f)

else:
    vocab, word2id, id2word = build_dict(seqs)
    pickle.dump(vocab, open(os.path.join(data_path, "lm_vocab.pkl"), "wb" ))
    pickle.dump(word2id, open(os.path.join(data_path, "lm_word2id.pkl"), "wb" ))
    pickle.dump(id2word, open(os.path.join(data_path, "lm_id2word.pkl"), "wb" ))

# %%
# example of first 10 word2id
for index, word in enumerate(word2id.keys()):
    print({word: word2id[word]})
    if index == 9:
        break
# Out:
# {'<pad>': 0}
# {'<s>': 1}
# {'</s>': 2}
# {'<unk>': 3}
# {'films': 4}
# {'adapted': 5}
# {'from': 6}
# {'comic': 7}
# {'books': 8}
# {'have': 9}

# %%
# example of first 10 id2word
for index, id in enumerate(id2word.keys()):
    print({id: id2word[id]})
    if index == 9:
        break
# Out:
# {0: '<pad>'}
# {1: '<s>'}
# {2: '</s>'}
# {3: '<unk>'}
# {4: 'films'}
# {5: 'adapted'}
# {6: 'from'}
# {7: 'comic'}
# {8: 'books'}
# {9: 'have'}

# %%
class LM_Dataset(data.Dataset):

    def __init__(self, pos_path, neg_path , word2id):
        
        #(add+)
        self.pos_seqs = open(pos_path).readlines()
        self.pos_labels = [0] * len(self.pos_seqs)
        self.neg_seqs = open(neg_path).readlines()
        self.neg_labels = [1] * len(self.neg_seqs)
        self.seqs = self.pos_seqs + self.neg_seqs # concat pos_seqs and neg_seqs
        self.labels = self.pos_labels + self.neg_labels
        
        self.word2id = word2id


    def __getitem__(self, index): # 가장 중요한 part Dataset 을 상속한 클래스는 이 부분을 overriding 해줘야함. 
        """Returns one data pair (source and sentiment)."""
        seqs = self.seqs[index]
        seqs = self.process(seqs, self.word2id)
        sentiment_labels = self.labels[index]
        return seqs, sentiment_labels

    def __len__(self): # 필수적인 클래스 이 부분을 무조건 overriding 해야함 
        return len(self.seqs) # 데이터 갯수 return 
                    
    def process(self, seq, word2id):
        sequence = []
        sequence.append(word2id["<s>"])
        words = seq.strip().split(' ')
        if len(words) <= 250: # max seq_len = 100
            for word in words:
                if word in word2id:
                    sequence.append(word2id[word]) # 
                else:
                    sequence.append(3) # replace by <unk> token
        sequence.append(word2id["</s>"])
        sequence = torch.Tensor(sequence)
        return sequence

# %% [markdown]
# ### Batch 를 구성해보겠습니다.
# Q : 우리의 문장에서 항상 단어의 갯수는 일정한가요?
#
# 문제점: Tensor로 변환하기 위해서는 추가 처리 필요 . eg. Sentence1 : W1 , W2, W3 ,W4 / Sentence : W1 , W2 ,W3 ->  2*3이 맞나요? 2*4가 맞나요?
#
# 해결법 : Batch * max_length  Tensor로 변환합니다. eg. 2*4의 경우 2 번째 문장의 마지막에 PAD_token을 처리해줍니다. Index 보통 : 0

# %%
def batch(iterable, n=1):
    args = [iter(iterable)] * n
    return zip_longest(*args)


def pad_tensor(vec, pad, value=0, dim=0):
    """
    pad token으로 채우는 용도 
    args:
        vec - tensor to pad
        pad - the size to pad to
        dim - dimension to pad
    return:
        a new tensor padded to 'pad' in dimension 'dim'
    """
    pad_size = pad - vec.shape[0]

    if len(vec.shape) == 2:
        zeros = torch.ones((pad_size, vec.shape[-1])) * value
    elif len(vec.shape) == 1:
        zeros = torch.ones((pad_size,)) * value
    else:
        raise NotImplementedError
    return torch.cat([torch.Tensor(vec), zeros], dim=dim)

# %% [markdown]
# ![대체 텍스트](./figures/sorted.jpg)

# %%
def collate_fn(batch, values=(0, 0), dim=0):
    """
    데이터 로더에 들어가기전에 batch화 할 때 거치는 함수 
    args:
        batch - list of (tensor, label)
    reutrn:
        xs - a tensor of all examples in 'batch' after padding
        ys - a LongTensor of all labels in batch
        ws - a tensor of sequence lengths
    """

    sequence_lengths = torch.Tensor([int(x[0].shape[dim]) for x in batch]) # 각 batch 마다 길이를 얻어내고 
    sequence_lengths, xids = sequence_lengths.sort(descending=True) # 감소하는 순서로 정렬
    # find longest sequence (가장 긴 sequence의 길이를 구함 )
    max_len = max(map(lambda x: x[0].shape[dim], batch))
    # pad according to max_len (max length 만큼 padd를 추가 )
    batch = [(pad_tensor(x, pad=max_len, dim=dim), label) for (x, label) in batch]

    # stack all
    xs = torch.stack([x[0] for x in batch], dim=0)
    xs = xs[xids].contiguous() # decreasing order로 다시 나열
    
    labels = [x[1] for x in batch]
    labels = [labels[i] for i in xids] # decreasing order로 다시 나열
    
    return xs.long(), sequence_lengths.int(), torch.Tensor(labels)

# %% [markdown]
# ### Build Language model

# %% [markdown]
# ### Example  pack padded

# %%
a = [torch.tensor([1,2,3]), torch.tensor([3,4])]
b = torch.nn.utils.rnn.pad_sequence(a, batch_first=True)
b
# Out:
# tensor([[1, 2, 3],
#         [3, 4, 0]])

# %%
pack_b=torch.nn.utils.rnn.pack_padded_sequence(b, batch_first=True, lengths=[3,2])
pack_b
# Out:
# PackedSequence(data=tensor([1, 3, 2, 4, 3]), batch_sizes=tensor([2, 2, 1]), sorted_indices=None, unsorted_indices=None)

# %%
rnn_utils.pad_packed_sequence(pack_b,batch_first=True,padding_value=0.)
# Out:
# (tensor([[1, 2, 3],
#          [3, 4, 0]]), tensor([3, 2]))

# %% [markdown]
# ## Model

# %%
class LM(nn.Module):
    def __init__(self, config, vocab_size):
        super(LM, self).__init__()
        self.vocab_size = vocab_size # get vocabulary size 
        self.embedding = nn.Embedding(self.vocab_size, config["embedding_size"])  # initialize embedding layer 
        self.rnn = nn.RNN(input_size=config["embedding_size"], hidden_size=config["hidden_size"], num_layers=config["decoder_layers"],
                          dropout=config["dropout"], batch_first=True) # defined rnn layer 
        self.outputs2vocab = nn.Linear(config["hidden_size"], self.vocab_size) # linear layer to predict the sentiment
    def forward(self,input, lengths):
        # ---------------- fill in ------------------------ 
        batch_size = input.size(0) # get batch_size
        input_embedding = self.embedding(input) # embedding layer  (B,L) -> (B,L ,hidden)
        packed_input = rnn_utils.pack_padded_sequence(input_embedding, lengths, batch_first=True) # pack sequence 
        outputs, _ = self.rnn(packed_input) # rnn 
        padded_outputs = rnn_utils.pad_packed_sequence(outputs, batch_first=True, padding_value=0.)[0] # packed sequence 
        padded_outputs = padded_outputs.contiguous()
        outputs = self.outputs2vocab(padded_outputs)
        logits = outputs.contiguous().view(-1, self.vocab_size)
        # ---------------- fill in ------------------------ 
        return logits

# %%
config = {
  "epochs": 1,
  "hidden_size": 64,
  "decoder_layers": 1,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
train_dataset = LM_Dataset(os.path.join(data_path, "lm_data/pos/train.txt"), os.path.join(data_path, "lm_data/neg/train.txt"), word2id)
train_data_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=True,
                                          collate_fn=collate_fn)

valid_dataset = LM_Dataset(os.path.join(data_path, "lm_data/pos/valid.txt"), os.path.join(data_path, "lm_data/neg/valid.txt"), word2id)
valid_data_loader = torch.utils.data.DataLoader(dataset=valid_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=False,
                                          collate_fn=collate_fn)
test_dataset = LM_Dataset(os.path.join(data_path, "lm_data/pos/test.txt"), os.path.join(data_path, "lm_data/neg/test.txt"), word2id)
test_data_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=False,
                                          collate_fn=collate_fn)

# %%
def lm_train(model, optimizer, train_loader, epoch,n_epochs):
    
    losses = []

    model.train() # train mode
    n_iter = 0
    for batch in train_loader:
        input, input_lengths, _ = batch 
        output = model(input[:,:-1].contiguous().to(device),(input_lengths-1))
        loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0).to(device)
        target = input[:,1:].contiguous().view(-1) 
        loss = loss_fn(output,target.to(device))
        losses.append(loss.item())
        # ------------------ fill in -------------------
        # Reset gradients
        optimizer.zero_grad()
        # Compute gradients
        loss.backward()
        # step optimzier
        optimizer.step() 
        # ------------------ fill in -------------------
        n_iter+=1 # count number of trained sentences
        if n_iter % 100 == 0: # print loss info for every 100 iteration steps
            print ('\n [{}] current_iter_loss= {:05.3f}'.format(n_iter,loss))
  
    print ('\n Epoch({}/{}) avg_loss= {:05.3f}'.format(epoch+1,n_epochs,np.mean(losses)))
    
    return model, optimizer

# %%
def lm_eval(model, loader):
    losses = []

    model.eval() # valid mode
    n_iter = 0
 
    for batch in loader:
        input, input_lengths, _ = batch
        output = model(input[:,:-1].contiguous().to(device),(input_lengths-1))
        loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0).to(device)
        target = input[:,1:].contiguous().view(-1)
        loss = loss_fn(output,target.to(device))
        losses.append(loss.item())
    
    return losses

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = LM(config, vocab_size=len(vocab))
optimizer = torch.optim.Adam(model.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = lm_train(model.to(device),optimizer, train_data_loader, epoch,config["epochs"]) # train
    valid_loss = lm_eval(model.to(device), valid_data_loader) # valid
    print ('\n              avg_valid loss= {:05.3f}'.format(np.mean(valid_loss)))
    test_loss = lm_eval(model.to(device), test_data_loader) # test
    print ('\n              avg_test loss= {:05.3f}'.format(np.mean(test_loss)))
# Out:
#  [100] current_iter_loss= 6.805
#
#  [200] current_iter_loss= 6.690
#
#  [300] current_iter_loss= 6.871
#
#  [400] current_iter_loss= 6.620
#
#  [500] current_iter_loss= 6.526
#
#  [600] current_iter_loss= 6.351
#
#  [700] current_iter_loss= 6.459
#
#  [800] current_iter_loss= 6.230
#
#  [900] current_iter_loss= 6.101
#
#  [1000] current_iter_loss= 6.717
#
#  [1100] current_iter_loss= 6.111
#
#  [1200] current_iter_loss= 6.168
#
#  [1300] current_iter_loss= 5.823
#
#  [1400] current_iter_loss= 5.912
#
#  [1500] current_iter_loss= 6.136
#
#  [1600] current_iter_loss= 6.307
#
#  [1700] current_iter_loss= 5.912
#
#  [1800] current_iter_loss= 5.922
#
#  [1900] current_iter_loss= 5.825
#
#  Epoch(1/1) avg_loss= 6.349
#
#               avg_valid loss= 5.855
#
#               avg_test loss= 5.710

# %% [markdown]
# ### Layer 를 더 깊게

# %%
config = {
  "epochs": 1,
  "hidden_size": 64,
  "decoder_layers": 3,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = LM(config, vocab_size=len(vocab))
optimizer = torch.optim.Adam(model.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = lm_train(model.to(device),optimizer, train_data_loader, epoch,config["epochs"]) # train
    valid_loss = lm_eval(model.to(device), valid_data_loader) # valid
    print ('\n              avg_valid loss= {:05.3f}'.format(np.mean(valid_loss)))
    test_loss = lm_eval(model.to(device), test_data_loader) # test
    print ('\n              avg_test loss= {:05.3f}'.format(np.mean(test_loss)))
# Out:
#  [100] current_iter_loss= 6.864
#
#  [200] current_iter_loss= 6.900
#
#  [300] current_iter_loss= 6.878
#
#  [400] current_iter_loss= 6.804
#
#  [500] current_iter_loss= 6.679
#
#  [600] current_iter_loss= 6.436
#
#  [700] current_iter_loss= 6.746
#
#  [800] current_iter_loss= 6.506
#
#  [900] current_iter_loss= 6.395
#
#  [1000] current_iter_loss= 6.573
#
#  [1100] current_iter_loss= 6.221
#
#  [1200] current_iter_loss= 6.292
#
#  [1300] current_iter_loss= 6.204
#
#  [1400] current_iter_loss= 6.374
#
#  [1500] current_iter_loss= 6.112
#
#  [1600] current_iter_loss= 6.155
#
#  [1700] current_iter_loss= 5.991
#
#  [1800] current_iter_loss= 6.161
#
#  [1900] current_iter_loss= 6.005
#
#  Epoch(1/1) avg_loss= 6.504
#
#               avg_valid loss= 5.970
#
#               avg_test loss= 5.870

# %% [markdown]
# ### GRU로 변경하기

# %%
class LM(nn.Module):
    def __init__(self, config, vocab_size):
        super(LM, self).__init__()
        self.vocab_size = vocab_size # get vocabulary size 
        self.embedding = nn.Embedding(self.vocab_size, config["embedding_size"])  # initialize embedding layer 
        # ------------------------- fill in --------------------------------
        self.rnn = nn.RNN(input_size=config["embedding_size"], hidden_size=config["hidden_size"], num_layers=config["decoder_layers"], 
                          dropout=config["dropout"], batch_first=True) # defined rnn layer 
        self.outputs2vocab = nn.Linear(config["hidden_size"], self.vocab_size) # linear layer to predict the sentiment
        # ------------------------- fill in --------------------------------
    def forward(self,input, lengths):
        batch_size = input.size(0) # get batch_size
        input_embedding = self.embedding(input) # embedding layer  (B,L) -> (B,L ,hidden)
        packed_input = rnn_utils.pack_padded_sequence(input_embedding, lengths, batch_first=True) # pack sequence 
        outputs, _ = self.rnn(packed_input)   # rnn 
        padded_outputs = rnn_utils.pad_packed_sequence(outputs, batch_first=True, padding_value=0.)[0] # packed sequence 
        padded_outputs = padded_outputs.contiguous()
        outputs = self.outputs2vocab(padded_outputs) 
        logits = outputs.contiguous().view(-1, self.vocab_size)
        return logits

# %%
config = {
  "epochs": 1,
  "hidden_size": 64,
  "decoder_layers": 3,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = LM(config, vocab_size=len(vocab))
optimizer = torch.optim.Adam(model.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = lm_train(model.to(device),optimizer, train_data_loader, epoch,config["epochs"]) # train
    valid_loss = lm_eval(model.to(device), valid_data_loader) # valid
    print ('\n              avg_valid loss= {:05.3f}'.format(np.mean(valid_loss)))
    test_loss = lm_eval(model.to(device), test_data_loader) # test
    print ('\n              avg_test loss= {:05.3f}'.format(np.mean(test_loss)))
# Out:
#  [100] current_iter_loss= 6.788
#
#  [200] current_iter_loss= 6.802
#
#  [300] current_iter_loss= 6.978
#
#  [400] current_iter_loss= 6.774
#
#  [500] current_iter_loss= 6.891
#
#  [600] current_iter_loss= 6.621
#
#  [700] current_iter_loss= 6.605
#
#  [800] current_iter_loss= 6.738
#
#  [900] current_iter_loss= 6.367
#
#  [1000] current_iter_loss= 6.311
#
#  [1100] current_iter_loss= 6.535
#
#  [1200] current_iter_loss= 6.339
#
#  [1300] current_iter_loss= 6.665
#
#  [1400] current_iter_loss= 6.257
#
#  [1500] current_iter_loss= 6.458
#
#  [1600] current_iter_loss= 6.310
#
#  [1700] current_iter_loss= 6.417
#
#  [1800] current_iter_loss= 6.177
#
#  [1900] current_iter_loss= 6.159
#
#  Epoch(1/1) avg_loss= 6.598
#
#               avg_valid loss= 6.054
#
#               avg_test loss= 5.973

# %% [markdown]
# # Chatper 3

# %% [markdown]
# # Sentiment Classfication

# %%
class Sentiment_Dataset(data.Dataset):

    def __init__(self, path , word2id):
        self.seqs = open(path).readlines()
        self.word2id = word2id

    def __getitem__(self, index):
        """Returns one data pair (source and sentiment)."""
        seqs = self.seqs[index]
        seqs, label = self.process(seqs, self.word2id)
        return seqs, label

    def __len__(self):
        return len(self.seqs)
                    
    def process(self, seq, word2id):
        label = 0 # default label "pos"
        sequence = []
        sequence.append(word2id["<s>"])
        words = seq.strip().split(' ')
        for i in range(0, len(words)-1):
            current_word = words[i]
            if "negative" == words[len(words)-1]: #if label is "neg", then 1
                label = 1
            if current_word in word2id:
                sequence.append(word2id[current_word])
            else:
                sequence.append(3) # replace by <unk> token
        sequence.append(word2id["</s>"])
        sequence = torch.Tensor(sequence)
        return sequence, label

# %%
class Sentiment_Classification(nn.Module):
    """
    IMDb 영화 리뷰 감성분류 모델
    """
    def __init__(self, config, vocab_size):
        """
        args:
            config     - hyperparameters
            vocab_size - vocab_size
        return:
            None
        """
        super(Sentiment_Classification, self).__init__()
        self.vocab_size = vocab_size
        # ------------------------- fill in --------------------------------
        self.embedding = nn.Embedding(self.vocab_size, config["embedding_size"]) # embedding layer 
        self.rnn = nn.RNN(input_size=config["embedding_size"], hidden_size=config["hidden_size"], 
                          num_layers=config["num_layers"],dropout=config["dropout"],bidirectional = config['bidirectional'] , batch_first=True)
        self.bidirectional = config['bidirectional']
        self.num_layers = config['num_layers']
        if self.bidirectional:
            self.hidden_size = 2 * config['hidden_size']
        else:
            self.hidden_size = config['hidden_size']
        self.outputs = nn.Sequential(
            # 3 layer mlp with LeakyReLU(0.2) in between, last activation is sigmoid
            nn.Linear(self.hidden_size, self.hidden_size),
            nn.LeakyReLU(0.2),
            nn.Linear(self.hidden_size, self.hidden_size),
            nn.LeakyReLU(0.2),
            nn.Linear(self.hidden_size, 1),
            nn.Sigmoid()
        )
        # ------------------------- fill in --------------------------------
    def forward(self,input, lengths):
        """
        args:
            input   - setences
            lengths - setence lengths
        return:
            outputs - positive or negative
        """
        batch_size = input.size(0)
        input_embedding = self.embedding(input)
        packed_input = rnn_utils.pack_padded_sequence(input_embedding, lengths, batch_first=True)
        _, hidden = self.rnn(packed_input)

        if self.bidirectional:
            batch_size = hidden.size()[1]
            hidden = hidden.view(self.num_layers,2,batch_size,-1)
            hidden = hidden.permute(2,0,1,3).contiguous().view(batch_size,self.num_layers,-1)
        else:
            hidden = hidden.permute(1,0,2)
            
        hidden = hidden[:,-1,:]
        outputs = self.outputs(hidden)
        outputs = outputs.squeeze(1)
        return outputs

# %%
def sentiment_trainer(model, optimizer, loaders, epoch,n_epochs):
    """
    args:
        model     - sentiment model
        optimizer - adam
        loaders   - valid, train loaders
    return:
        model, optimizer
    """
    losses = []
    total_accuracy = []
    val_losses = []
    val_total_accuracy = []
    n_iter = 0
    for split in loaders.keys():
        if split == "train":
            for batch in loaders[split]:
        # ------------------------- fill in --------------------------------
                model.train() # train mode
                input, input_lengths, target_label = batch
                predict_label = model(input.to(device), input_lengths)
                loss_fn = nn.BCELoss().to(device)
                loss = loss_fn(predict_label,target_label.to(device))
                losses.append(loss.item())

                # Calculate accuracy
                x_acc = predict_label.round().cpu().detach().numpy()
                y_acc = target_label.cpu().detach().numpy()
                accuracy = accuracy_score(x_acc,y_acc)
                total_accuracy.append(accuracy)
                # Reset gradients
                optimizer.zero_grad()
                # Compute gradients
                loss.backward()
                # step optimzier
                optimizer.step() 
        # ------------------------- fill in --------------------------------
                n_iter+=1 # count number of trained sentences
                if n_iter % 100 == 0: # print loss only if it's training stage
                    print ('\n [{}] current_iter_loss= {:05.3f} acc= {:05.3f}'.format(n_iter,loss,accuracy))
                
        elif split == "valid":
            model.eval() # eval mode
            for batch in loaders[split]:
                input, input_lengths, target_label = batch
                predict_label = model(input.to(device),input_lengths)
                loss_fn = nn.BCELoss().to(device)
                loss = loss_fn(predict_label,target_label.to(device))
                val_losses.append(loss.item())
                # Calculate accuracy
                x_acc = predict_label.round().cpu().detach().numpy()
                y_acc = target_label.cpu().detach().numpy()
                accuracy = accuracy_score(x_acc,y_acc)
                val_total_accuracy.append(accuracy)
  
    print ('\n Epoch({}/{}) avg train_loss= {:05.3f} train_acc= {:05.3f} val_loss= {:05.3f} val_acc= {:05.3f}'
           .format(
               epoch+1,n_epochs,np.mean(losses), np.mean(total_accuracy), 
                   np.mean(val_losses), np.mean(val_total_accuracy)
              )
          )
    
    return model, optimizer

# %%
def idx2word(idx, i2w, pad_idx):
    """
    index로 이루어진 문장을 받아,
    word 문장으로 전환
    """

    sent_str = [str()]*len(idx)

    for i, sent in enumerate(idx):

        for word_id in sent:

            if word_id == pad_idx:
                break
            sent_str[i] += i2w[int(word_id)] + " "

        sent_str[i] = sent_str[i].strip()


    return sent_str[0]

# %%
def evaluate(model, loader, epoch,n_epochs, id2word):
    """
    각 epoch 마다 model에 대한 test및, prediction결과 추출
    """
    losses = []
    total_accuracy = []
    model.eval()
    for batch in loader:
        input, input_lengths, target_label = batch
        predict_label = model(input.to(device),input_lengths)
        loss_fn = nn.BCELoss().to(device)
        loss = loss_fn(predict_label,target_label.to(device))
        losses.append(loss.item())
        # Calculate accuracy
        x_acc = predict_label.round().cpu().detach().numpy()
        y_acc = target_label.cpu().detach().numpy()
        accuracy = accuracy_score(x_acc,y_acc)
        total_accuracy.append(accuracy)

    print ('\n Epoch({}/{}) avg test_loss= {:05.3f} test_acc= {:05.3f}'
        .format(epoch+1,n_epochs,np.mean(losses), np.mean(total_accuracy))
    )
    
    # test inference
    print (idx2word(input, id2word, 0))
    predict_label = model(input.to(device),input_lengths)
    ans = {0: 'positive', 1:'negative'}
    print('\n Pred: {}, Ans: {}'
          .format(ans[predict_label[0].round().item()], ans[target_label[0].item()])
         )

# %%
seqs = open(os.path.join(data_path, "/content/drive/MyDrive/실습1/lm_data/new_IMDb/train.tok")).readlines()
vocab, word2id, id2word = build_dict(seqs)
# Out:
# Building vocab and dict..
# Number of unique words: 119621
# Finised building vocab and dict!

# %%
# Building vocab or loading existing vocab
path = "/content/drive/MyDrive/실습1/lm_id2word.pkl"
if os.path.isfile(path):
    with open("/content/drive/MyDrive/실습1/lm_id2word.pkl", "rb") as f:
        id2word = pickle.load(f)
    with open("/content/drive/MyDrive/실습1/lm_word2id.pkl", "rb") as f:
        word2id = pickle.load(f)
    with open("/content/drive/MyDrive/실습1/lm_vocab.pkl", "rb") as f:
        vocab = pickle.load(f)

else: # file does not exist
    vocab, word2id, id2word = build_dict(seqs)
    pickle.dump(vocab, open("/content/drive/MyDrive/실습1/lm_vocab.pkl", "wb" ))
    pickle.dump(word2id, open("/content/drive/MyDrive/실습1/lm_word2id.pkl", "wb" ))
    pickle.dump(id2word, open("/content/drive/MyDrive/실습1/lm_id2word.pkl", "wb" ))

# %%
config = {
  "epochs": 5,
  "hidden_size": 64,
  "bidirectional": True,
  "num_layers": 4,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
# constructing train dataset
train_dataset = Sentiment_Dataset(os.path.join(data_path, "lm_data/new_IMDb/train.tok"), word2id)
train_data_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=True,
                                          collate_fn=collate_fn)
# constructing valid dataset
valid_dataset = Sentiment_Dataset(os.path.join(data_path, "lm_data/new_IMDb/valid.tok"), word2id)
valid_data_loader = torch.utils.data.DataLoader(dataset=valid_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=True,
                                          collate_fn=collate_fn)
# constructing test dataset
test_dataset = Sentiment_Dataset(os.path.join(data_path, "lm_data/new_IMDb/test.tok"), word2id)
test_data_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=True,
                                          collate_fn=collate_fn)

loaders = {"train": train_data_loader, "valid": valid_data_loader}

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Init sentiment model
model2 = Sentiment_Classification(config, vocab_size=len(vocab))
model2 = model2.to(device)
optimizer = torch.optim.Adam(model2.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = sentiment_trainer(model2,optimizer, loaders, epoch,config["epochs"])
    evaluate(model, test_data_loader, epoch,config["epochs"], id2word)
# Out:
#  [100] current_iter_loss= 0.681 acc= 0.688
#
#  [200] current_iter_loss= 0.701 acc= 0.438
#
#  [300] current_iter_loss= 0.688 acc= 0.562
#
#  [400] current_iter_loss= 0.690 acc= 0.469
#
#  [500] current_iter_loss= 0.685 acc= 0.469
#
#  [600] current_iter_loss= 0.684 acc= 0.500
#
#  [700] current_iter_loss= 0.672 acc= 0.625
#
#  [800] current_iter_loss= 0.689 acc= 0.469
#
#  [900] current_iter_loss= 0.691 acc= 0.531
#
#  Epoch(1/5) avg train_loss= 0.692 train_acc= 0.520 val_loss= 0.694 val_acc= 0.530
#
#  Epoch(1/5) avg test_loss= 0.688 test_acc= 0.540
# <s> " <unk> movie is just <unk> tries to copy some effects borrowed to a creative director like <unk> in " " <unk> <unk> " , " but it is too much . <unk> <unk> are pretty bad , some of the worst <unk> have ever heard , <unk> <unk> is not convincing ( <unk> have almost never found him very convincing ) , his father in the movie plays very badly , the story is dumb , the ending is <unk> <unk> think <unk> have not dislike a movie so much since " " le <unk> <unk> <unk> " " ( brotherhood of the wolf ) from <unk> <unk> ( and <unk> watch / see about <unk> movies a year ) , but at least that movie had some action and lots of good <unk> had never commented here ( only rated ) , and when <unk> saw the rating and the comments , <unk> thought <unk> had to write something <unk> guess we won 't have problems to sell the <unk> we were offered : not such a bad movie in our ( large ) collection ! ! ! <unk> am open minded ( <unk> watch <unk> , westerns , drama , comedies , silents , horror , fantasy <unk> movies ! ) , but this movie was so boring that <unk> felt like <unk> had lost one hour and a half . , " </s>
#
#  Pred: positive, Ans: negative
#
#  [100] current_iter_loss= 0.694 acc= 0.469
#
#  [200] current_iter_loss= 0.689 acc= 0.594
#
#  [300] current_iter_loss= 0.698 acc= 0.500
#
#  [400] current_iter_loss= 0.696 acc= 0.406
#
#  [500] current_iter_loss= 0.697 acc= 0.438
#
#  [600] current_iter_loss= 0.694 acc= 0.469
#
#  [700] current_iter_loss= 0.691 acc= 0.625
#
#  [800] current_iter_loss= 0.695 acc= 0.469
#
#  [900] current_iter_loss= 0.696 acc= 0.500
#
#  Epoch(2/5) avg train_loss= 0.693 train_acc= 0.507 val_loss= 0.693 val_acc= 0.490
#
#  Epoch(2/5) avg test_loss= 0.693 test_acc= 0.570
# <s> " <unk> after renting and watching this movie several years ago , a friend and <unk> decided that it defined the absolute zero on the movie scale . <unk> was nothing about the movie that could have been done worse than it was . <unk> this day we still rate movies , even very bad ones , by how much better than " " <unk> <unk> <unk> " " they <unk> long time ago <unk> saw an interview with <unk> <unk> , who wrote the screenplays for , among other things , " " <unk> <unk> " " and " " <unk> of a <unk> <unk> , " " and she related that she had been asked to write a screenplay for the <unk> <unk> ' book " " <unk> <unk> <unk> . " " <unk> said that she sent in a treatment and it was rejected because they didn 't think she understood the difficulties of a female screenwriter in <unk> . <unk> then said " " <unk> think they got someone else to write it . " " <unk> interview was filmed before the movie was released . <unk> died in 1981 , and <unk> bet the first thing she did on arrival in heaven was personally thank <unk> for saving her from involvement in the result . , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.694 acc= 0.531
#
#  [200] current_iter_loss= 0.694 acc= 0.500
#
#  [300] current_iter_loss= 0.698 acc= 0.406
#
#  [400] current_iter_loss= 0.690 acc= 0.625
#
#  [500] current_iter_loss= 0.688 acc= 0.594
#
#  [600] current_iter_loss= 0.693 acc= 0.500
#
#  [700] current_iter_loss= 0.696 acc= 0.375
#
#  [800] current_iter_loss= 0.681 acc= 0.531
#
#  [900] current_iter_loss= 0.686 acc= 0.656
#
#  Epoch(3/5) avg train_loss= 0.693 train_acc= 0.510 val_loss= 0.694 val_acc= 0.512
#
#  Epoch(3/5) avg test_loss= 0.691 test_acc= 0.549
# <s> " <unk> movie should not be watched as it was meant to be a flop . <unk> <unk> <unk> first wanted to make this a remake of classic <unk> movie " " <unk> " , " but after having problems with the original makers decided to go ahead with the project and <unk> i guess leave all the good parts of the movie ( acting , script , songs , music , comedy , action etc ) out and shoot the movie just because he already happen to hire the crew . <unk> of money , waste of time . <unk> making movies like <unk> , <unk> , and <unk> he pulled a <unk> ( <unk> ) on us ; <unk> were you thinking <unk> ? <unk> , the story is , though hard to follow , is almost like the <unk> <unk> . <unk> <unk> playing <unk> ( <unk> , <unk> ) and <unk> , new kid on the block playing <unk> ( <unk> , <unk> ) . <unk> " " bad yet funny " " friends help a cop capture a bad guy first . <unk> in the movie , now <unk> cop hires them as personal security and <unk> from the hands of a very most wanted <unk> played by <unk> <unk> . <unk> case you haven 't been watching <unk> movies , the <unk> guys win in the end . <unk> <unk> just saved you 3 precious hours of your life ! , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.691 acc= 0.562
#
#  [200] current_iter_loss= 0.635 acc= 0.781
#
#  [300] current_iter_loss= 0.684 acc= 0.625
#
#  [400] current_iter_loss= 0.654 acc= 0.594
#
#  [500] current_iter_loss= 0.777 acc= 0.469
#
#  [600] current_iter_loss= 0.679 acc= 0.594
#
#  [700] current_iter_loss= 0.638 acc= 0.719
#
#  [800] current_iter_loss= 0.616 acc= 0.688
#
#  [900] current_iter_loss= 0.684 acc= 0.500
#
#  Epoch(4/5) avg train_loss= 0.680 train_acc= 0.566 val_loss= 0.673 val_acc= 0.594
#
#  Epoch(4/5) avg test_loss= 0.667 test_acc= 0.590
# <s> " <unk> is a lot of crap coming out of <unk> <unk> friend , sends me movies now and again , as a surprise , it 's <unk> turned it on and couldn 't stop watching , it is a drama , but with a odd twist . <unk> if <unk> , as in <unk> , had a super power . <unk> is sad and poetic at the same time . <unk> should take notice of the new <unk> cinema , they are telling stories that are not about big explosions and cgi . <unk> takes a simple basic premise and tells a story , without a spectacle . <unk> is a lot like an <unk> film with a dark <unk> twist . <unk> it 's not perfect , but nothing ever is . <unk> know what the power is but it is never explained , nor totally realized until the end . <unk> becomes secondary to the emotion of the story . <unk> don 't want to see a remake , it is too cool as is , the <unk> system would , as usual , mess it up . <unk> is top notch all around . <unk> and <unk> work are far above most of the crap that is out there . <unk> to all involved , and <unk> will turn a lot of people on to this independent epic . <unk> + + + + + <unk> you can find i , watch it . , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.586 acc= 0.656
#
#  [200] current_iter_loss= 0.726 acc= 0.375
#
#  [300] current_iter_loss= 0.593 acc= 0.688
#
#  [400] current_iter_loss= 0.518 acc= 0.844
#
#  [500] current_iter_loss= 0.652 acc= 0.625
#
#  [600] current_iter_loss= 0.627 acc= 0.594
#
#  [700] current_iter_loss= 0.622 acc= 0.625
#
#  [800] current_iter_loss= 0.503 acc= 0.812
#
#  [900] current_iter_loss= 0.626 acc= 0.656
#
#  Epoch(5/5) avg train_loss= 0.638 train_acc= 0.637 val_loss= 0.642 val_acc= 0.632
#
#  Epoch(5/5) avg test_loss= 0.631 test_acc= 0.644
# <s> " <unk> claim no matter how hard <unk> seek <unk> 'll never find a better movie version of " " <unk> " . " <unk> you love <unk> <unk> 's magnificent masterpieces " " <unk> ado about nothing " " ( 1993 ) and " " <unk> " " ( 1996 ) as much as <unk> do <unk> <unk> dead certain you 'll also find <unk> <unk> 's " " <unk> " " irresistible . <unk> <unk> has been in a various splendid roles during his career . <unk> was quite terrific in " " <unk> n the hood " " ( 1991 ) - <unk> <unk> always considered his amusing role of <unk> <unk> as his very greatest achievement . <unk> was , of course , way before <unk> saw <unk> plays the part of <unk> and he is probably in the most challenging role of his whole career but he does a brilliant , fantastic job . <unk> <unk> is absolutely charming <unk> and <unk> <unk> is just simply phenomenal in a most fascinating role of the story 's crooked , manipulate villain <unk> . <unk> " " <unk> " " is part of the absolute elite among <unk> 's ingenious works . <unk> deals with his favorite topics : <unk> , envy , <unk> and jealousy . <unk> movie adaptation is certainly one of the finest films <unk> <unk> seen that 's based on <unk> <unk> 's plays . , " </s>
#
#  Pred: positive, Ans: positive

# %% [markdown]
# ## No Bidirectional

# %%
config = {
  "epochs": 5,
  "hidden_size": 64,
  "bidirectional": True,
  "num_layers": 2,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model2 = Sentiment_Classification(config, vocab_size=len(vocab))
model2 = model2.to(device)
optimizer = torch.optim.Adam(model2.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = sentiment_trainer(model2,optimizer, loaders, epoch,config["epochs"])
    evaluate(model, test_data_loader, epoch,config["epochs"], id2word)
# Out:
#  [100] current_iter_loss= 0.695 acc= 0.500
#
#  [200] current_iter_loss= 0.703 acc= 0.375
#
#  [300] current_iter_loss= 0.687 acc= 0.625
#
#  [400] current_iter_loss= 0.685 acc= 0.594
#
#  [500] current_iter_loss= 0.680 acc= 0.562
#
#  [600] current_iter_loss= 0.681 acc= 0.625
#
#  [700] current_iter_loss= 0.702 acc= 0.344
#
#  [800] current_iter_loss= 0.700 acc= 0.438
#
#  [900] current_iter_loss= 0.690 acc= 0.562
#
#  Epoch(1/5) avg train_loss= 0.692 train_acc= 0.519 val_loss= 0.693 val_acc= 0.501
#
#  Epoch(1/5) avg test_loss= 0.683 test_acc= 0.564
# <s> " <unk> is a lot of crap coming out of <unk> <unk> friend , sends me movies now and again , as a surprise , it 's <unk> turned it on and couldn 't stop watching , it is a drama , but with a odd twist . <unk> if <unk> , as in <unk> , had a super power . <unk> is sad and poetic at the same time . <unk> should take notice of the new <unk> cinema , they are telling stories that are not about big explosions and cgi . <unk> takes a simple basic premise and tells a story , without a spectacle . <unk> is a lot like an <unk> film with a dark <unk> twist . <unk> it 's not perfect , but nothing ever is . <unk> know what the power is but it is never explained , nor totally realized until the end . <unk> becomes secondary to the emotion of the story . <unk> don 't want to see a remake , it is too cool as is , the <unk> system would , as usual , mess it up . <unk> is top notch all around . <unk> and <unk> work are far above most of the crap that is out there . <unk> to all involved , and <unk> will turn a lot of people on to this independent epic . <unk> + + + + + <unk> you can find i , watch it . , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.710 acc= 0.406
#
#  [200] current_iter_loss= 0.699 acc= 0.438
#
#  [300] current_iter_loss= 0.704 acc= 0.344
#
#  [400] current_iter_loss= 0.688 acc= 0.594
#
#  [500] current_iter_loss= 0.690 acc= 0.562
#
#  [600] current_iter_loss= 0.707 acc= 0.438
#
#  [700] current_iter_loss= 0.672 acc= 0.625
#
#  [800] current_iter_loss= 0.690 acc= 0.562
#
#  [900] current_iter_loss= 0.680 acc= 0.500
#
#  Epoch(2/5) avg train_loss= 0.689 train_acc= 0.543 val_loss= 0.690 val_acc= 0.550
#
#  Epoch(2/5) avg test_loss= 0.672 test_acc= 0.590
# <s> " <unk> is a lot of crap coming out of <unk> <unk> friend , sends me movies now and again , as a surprise , it 's <unk> turned it on and couldn 't stop watching , it is a drama , but with a odd twist . <unk> if <unk> , as in <unk> , had a super power . <unk> is sad and poetic at the same time . <unk> should take notice of the new <unk> cinema , they are telling stories that are not about big explosions and cgi . <unk> takes a simple basic premise and tells a story , without a spectacle . <unk> is a lot like an <unk> film with a dark <unk> twist . <unk> it 's not perfect , but nothing ever is . <unk> know what the power is but it is never explained , nor totally realized until the end . <unk> becomes secondary to the emotion of the story . <unk> don 't want to see a remake , it is too cool as is , the <unk> system would , as usual , mess it up . <unk> is top notch all around . <unk> and <unk> work are far above most of the crap that is out there . <unk> to all involved , and <unk> will turn a lot of people on to this independent epic . <unk> + + + + + <unk> you can find i , watch it . , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.651 acc= 0.625
#
#  [200] current_iter_loss= 0.676 acc= 0.594
#
#  [300] current_iter_loss= 0.711 acc= 0.562
#
#  [400] current_iter_loss= 0.677 acc= 0.594
#
#  [500] current_iter_loss= 0.622 acc= 0.656
#
#  [600] current_iter_loss= 0.662 acc= 0.562
#
#  [700] current_iter_loss= 0.712 acc= 0.469
#
#  [800] current_iter_loss= 0.691 acc= 0.562
#
#  [900] current_iter_loss= 0.770 acc= 0.438
#
#  Epoch(3/5) avg train_loss= 0.670 train_acc= 0.591 val_loss= 0.658 val_acc= 0.602
#
#  Epoch(3/5) avg test_loss= 0.619 test_acc= 0.661
# <s> " <unk> is a case of a bunch of people thinking they are so clever they have a story that fits the time . <unk> the all-around political conspiracies caught on camera in the years leading to the <unk> and a little later ? <unk> movies trying to cash in on <unk> ' o so powerful , o so mind numbing ' conspiracies were in fact caught in their own <unk> <unk> was never a fan of <unk> <unk> which <unk> find as much dated as others conspiracy stints of the time but <unk> was true to his main character and <unk> was a pretty engaging actor to observe . <unk> mean these conspiracy movies are mostly drowning in the character pool of noir heroes . <unk> of questions unanswered , lots of <unk> <unk> <unk> this takes at least <unk> to build a movie about such <unk> <unk> <unk> <unk> is a perfect example of its time : one political soup served with an idealistic character and an horrendous conspiracy <unk> its web around him . <unk> part is interesting in itself and the whole doesn 't get any better . <unk> fact you can tell how much it will be bad from the very first sequences piling up ' <unk> that ' murders without ever advancing any storyline . <unk> directing at its worst as most of the movie is one pompous accumulation of scenes revolving around violence <unk> brought under the viewer 's eyes . , " </s>
#
#  Pred: positive, Ans: negative
#
#  [100] current_iter_loss= 0.692 acc= 0.562
#
#  [200] current_iter_loss= 0.602 acc= 0.688
#
#  [300] current_iter_loss= 0.615 acc= 0.719
#
#  [400] current_iter_loss= 0.573 acc= 0.688
#
#  [500] current_iter_loss= 0.622 acc= 0.594
#
#  [600] current_iter_loss= 0.645 acc= 0.688
#
#  [700] current_iter_loss= 0.640 acc= 0.625
#
#  [800] current_iter_loss= 0.472 acc= 0.812
#
#  [900] current_iter_loss= 0.688 acc= 0.688
#
#  Epoch(4/5) avg train_loss= 0.630 train_acc= 0.647 val_loss= 0.594 val_acc= 0.669
#
#  Epoch(4/5) avg test_loss= 0.582 test_acc= 0.693
# <s> " <unk> my . <unk> can they make movies of such beauty , but that are so terribly bad . <unk> mean , even <unk> <unk> doesn 't make crap like this . <unk> is not even a hint of a decent story , multi-layered characters , or attraction . <unk> 's just a random sequence of pointless chatter joined together to make a ' movie ' . <unk> suppose only children up to 3 years of age could enjoy it , given the world is so utterly <unk> and the story so incoherent , that anyone older would be annoyed by it . <unk> then again , it 's far too scary for anyone under 6 years of age , that there 's probably no one that should watch this movie at <unk> my advice and stay far , far away from this movie . <unk> little daughter can make a better storyline , and though she probably <unk> 't able to draw pictures this pretty , her tales are much more worth listening to . <unk> please , in the name of whoever you believe in , do not expose your children to this piece of * * * * . <unk> 'll give it 2 out of 10 , and that 's exclusively for the graphics , because the story and character development are so awful they <unk> deserve a negative <unk> if you decide to watch it anyways <unk> remember that <unk> warned you . , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.581 acc= 0.625
#
#  [200] current_iter_loss= 0.690 acc= 0.469
#
#  [300] current_iter_loss= 0.646 acc= 0.594
#
#  [400] current_iter_loss= 0.669 acc= 0.656
#
#  [500] current_iter_loss= 0.709 acc= 0.438
#
#  [600] current_iter_loss= 0.670 acc= 0.625
#
#  [700] current_iter_loss= 0.654 acc= 0.656
#
#  [800] current_iter_loss= 0.716 acc= 0.531
#
#  [900] current_iter_loss= 0.524 acc= 0.750
#
#  Epoch(5/5) avg train_loss= 0.599 train_acc= 0.680 val_loss= 0.544 val_acc= 0.718
#
#  Epoch(5/5) avg test_loss= 0.568 test_acc= 0.716
# <s> " <unk> claim no matter how hard <unk> seek <unk> 'll never find a better movie version of " " <unk> " . " <unk> you love <unk> <unk> 's magnificent masterpieces " " <unk> ado about nothing " " ( 1993 ) and " " <unk> " " ( 1996 ) as much as <unk> do <unk> <unk> dead certain you 'll also find <unk> <unk> 's " " <unk> " " irresistible . <unk> <unk> has been in a various splendid roles during his career . <unk> was quite terrific in " " <unk> n the hood " " ( 1991 ) - <unk> <unk> always considered his amusing role of <unk> <unk> as his very greatest achievement . <unk> was , of course , way before <unk> saw <unk> plays the part of <unk> and he is probably in the most challenging role of his whole career but he does a brilliant , fantastic job . <unk> <unk> is absolutely charming <unk> and <unk> <unk> is just simply phenomenal in a most fascinating role of the story 's crooked , manipulate villain <unk> . <unk> " " <unk> " " is part of the absolute elite among <unk> 's ingenious works . <unk> deals with his favorite topics : <unk> , envy , <unk> and jealousy . <unk> movie adaptation is certainly one of the finest films <unk> <unk> seen that 's based on <unk> <unk> 's plays . , " </s>
#
#  Pred: positive, Ans: positive

# %% [markdown]
# ### GRU Model

# %%
class Sentiment_Classification(nn.Module):

    def __init__(self, config, vocab_size):
        super(Sentiment_Classification, self).__init__()
        self.vocab_size = vocab_size
        self.embedding = nn.Embedding(self.vocab_size, config["embedding_size"])
        # ------------------------- fill in --------------------------------
        # create GRU model with args: input_size, hidden_size, num_layers, dropout, bidirectional, and batch_first=True
        self.rnn = nn.RNN(input_size=config["embedding_size"], hidden_size=config["hidden_size"], 
                          num_layers=config["num_layers"],dropout=config["dropout"],bidirectional = config['bidirectional'] , batch_first=True)
        # ------------------------- fill in --------------------------------
        self.bidirectional = config['bidirectional']
        self.num_layers = config['num_layers']
        if self.bidirectional:
            self.hidden_size = 2*config['hidden_size']
        else:
            self.hidden_size = config['hidden_size']
        # ------------------------- fill in --------------------------------
        self.outputs = nn.Sequential(
            nn.Linear(self.hidden_size, self.hidden_size),
            nn.LeakyReLU(0.2),
            nn.Linear(self.hidden_size, self.hidden_size),
            nn.LeakyReLU(0.2),
            nn.Linear(self.hidden_size, 1),
            nn.Sigmoid()
        )
        # ------------------------- fill in --------------------------------
    def forward(self,input, lengths):
        batch_size = input.size(0)
        input_embedding = self.embedding(input) 
        packed_input = rnn_utils.pack_padded_sequence(input_embedding, lengths, batch_first=True)
        _, hidden = self.rnn(packed_input)
        
        if self.bidirectional:
            batch_size = hidden.size()[1]
            hidden = hidden.view(self.num_layers,2,batch_size,-1)
            hidden = hidden.permute(2,0,1,3).contiguous().view(batch_size,self.num_layers,-1)
        else:
            hidden = hidden.permute(1,0,2)
            
        hidden = hidden[:,-1,:]
        outputs = self.outputs(hidden)
        outputs = outputs.squeeze(1)
        return outputs

# %%
config = {
  "epochs": 5,
  "hidden_size": 64,
  "bidirectional": True,
  "num_layers": 3,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model2 = Sentiment_Classification(config, vocab_size=len(vocab))
model2 = model2.to(device)
optimizer = torch.optim.Adam(model2.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = sentiment_trainer(model2,optimizer, loaders, epoch,config["epochs"])
    evaluate(model, test_data_loader, epoch,config["epochs"], id2word)
# Out:
#  [100] current_iter_loss= 0.683 acc= 0.594
#
#  [200] current_iter_loss= 0.692 acc= 0.688
#
#  [300] current_iter_loss= 0.701 acc= 0.469
#
#  [400] current_iter_loss= 0.700 acc= 0.469
#
#  [500] current_iter_loss= 0.693 acc= 0.500
#
#  [600] current_iter_loss= 0.630 acc= 0.625
#
#  [700] current_iter_loss= 0.701 acc= 0.469
#
#  [800] current_iter_loss= 0.694 acc= 0.500
#
#  [900] current_iter_loss= 0.686 acc= 0.594
#
#  Epoch(1/5) avg train_loss= 0.691 train_acc= 0.526 val_loss= 0.692 val_acc= 0.525
#
#  Epoch(1/5) avg test_loss= 0.683 test_acc= 0.559
# <s> " <unk> love so much about this movie : the music , the cinematography , the acting , the story , and all the <unk> <unk> . <unk> because they are <unk> doesn 't mean they aren 't true ! <unk> is not perfect , it is a movie after all . <unk> <unk> are held in well-lit rooms with nice big <unk> and chairs , it was totally appropriate to portray it as the dark , cold scene they did in this film . <unk> also liked the scene with the angel waiting at the bus stop , smoking a cigarette . <unk> thought that was so cool . <unk> mean , <unk> believe that angels do watch over us . <unk> is one supposed to do while waiting ? <unk> is a way some people pass the time while waiting . <unk> loved the irony cause <unk> make such a deal about smoking . <unk> saw this movie 7 times in theaters in <unk> <unk> , and cried every time ! <unk> blows me away . <unk> <unk> <unk> watched it 3 times on video now and it still makes me cry every time . <unk> would jump at the chance to see it again on a big screen . <unk> hope the <unk> <unk> in <unk> <unk> will bring it back regularly at <unk> <unk> time , as a cult movie ( pun intended , but no offense intended ) . , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.675 acc= 0.625
#
#  [200] current_iter_loss= 0.624 acc= 0.719
#
#  [300] current_iter_loss= 0.695 acc= 0.562
#
#  [400] current_iter_loss= 0.706 acc= 0.469
#
#  [500] current_iter_loss= 0.686 acc= 0.562
#
#  [600] current_iter_loss= 0.690 acc= 0.562
#
#  [700] current_iter_loss= 0.651 acc= 0.688
#
#  [800] current_iter_loss= 0.690 acc= 0.562
#
#  [900] current_iter_loss= 0.695 acc= 0.438
#
#  Epoch(2/5) avg train_loss= 0.678 train_acc= 0.570 val_loss= 0.693 val_acc= 0.538
#
#  Epoch(2/5) avg test_loss= 0.688 test_acc= 0.526
# <s> " <unk> ' director <unk> <unk> returns with what must be one of the <unk> and at the same time most serious vampire flicks in movie <unk> the latest <unk> fad , vampires these days are supposed to be rather <unk> , asexual , <unk> <unk> instead of the evil <unk> sexual <unk> <unk> <unk> of yore . <unk> is the film you want to see if you want to remember the sticky thrills of the past <unk> well , at least in the second half . ' <unk> ' starts out with a lengthy character exposition culminating in a slightly different love story . <unk> vampire transformation of a priest is , over quite some time , <unk> by the romantic and sexual aspects of the story , which makes for some awkward viewing . <unk> the last 40 minutes or so are surprisingly gory . <unk> , maybe not so surprisingly if you know ' <unk> ' and ' <unk> <unk> a <unk> but that 's <unk> ' , but <unk> guess it 's fair to say that ' <unk> ' beats <unk> 's earlier films in terms of in-your-face violence . <unk> in all , be warned that this is neither art cinema nor a horror flick . <unk> may be too disgusting for many and too tame for some . ' <unk> ' is original , entertaining and fortunately a little less weird than <unk> <unk> 's earlier endeavors . , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.706 acc= 0.531
#
#  [200] current_iter_loss= 0.696 acc= 0.469
#
#  [300] current_iter_loss= 0.711 acc= 0.406
#
#  [400] current_iter_loss= 0.711 acc= 0.469
#
#  [500] current_iter_loss= 0.689 acc= 0.594
#
#  [600] current_iter_loss= 0.671 acc= 0.656
#
#  [700] current_iter_loss= 0.669 acc= 0.625
#
#  [800] current_iter_loss= 0.670 acc= 0.656
#
#  [900] current_iter_loss= 0.694 acc= 0.625
#
#  Epoch(3/5) avg train_loss= 0.687 train_acc= 0.546 val_loss= 0.691 val_acc= 0.520
#
#  Epoch(3/5) avg test_loss= 0.674 test_acc= 0.579
# <s> " <unk> have always loved old movies but this is one of my top ten favorites <unk> it has all the charm , 1940 's <unk> , and good old fashioned romance and it 's hilarious , to boot ! <unk> <unk> plays an independent single woman who writes cooking \ home life articles for a famous magazine <unk> under the premise that she is a married homemaker . <unk> the president of the magazine is under this delusion . <unk> a handsome <unk> , ( played by the talented <unk> <unk> ) just rescued off of a raft along with his buddy . <unk> simple wish is to stay at the homey <unk> the she writes so eloquently about and relax with her famous home-cooked meals . <unk> now has to frantically find a way to save her job and reputation <unk> add to this that her <unk> is in a hurry to tie the knot doesn 't help . <unk> humor is superb and the chemistry between the leading characters a lot of fun . <unk> in the character-actor nicknamed " " <unk> " " ( who fits this name completely ) it becomes even more adorable . <unk> has become my must-see movie that <unk> <unk> in with a cup of <unk> each <unk> season . <unk> wonderful , enjoyable movie to enjoy at <unk> or anytime ! , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.665 acc= 0.656
#
#  [200] current_iter_loss= 0.645 acc= 0.750
#
#  [300] current_iter_loss= 0.689 acc= 0.500
#
#  [400] current_iter_loss= 0.688 acc= 0.531
#
#  [500] current_iter_loss= 0.641 acc= 0.594
#
#  [600] current_iter_loss= 0.689 acc= 0.562
#
#  [700] current_iter_loss= 0.696 acc= 0.531
#
#  [800] current_iter_loss= 0.657 acc= 0.594
#
#  [900] current_iter_loss= 0.676 acc= 0.594
#
#  Epoch(4/5) avg train_loss= 0.679 train_acc= 0.572 val_loss= 0.711 val_acc= 0.511
#
#  Epoch(4/5) avg test_loss= 0.675 test_acc= 0.595
# <s> " <unk> <unk> film with absurdity . <unk> ( <unk> * ck <unk> ) tells the story of two young women who come together to kill and f * ck . <unk> of them is a porn star who escapes from her community after being raped and killing her boyfriend . <unk> one is a hooker who kills her flatmate and sees her boyfriend being shot dead . <unk> those incidents they meet at a tube station ( both misses the last train ) then the whole thing starts . <unk> find a bound and come very close . <unk> abuse men sexually , take drugs , drive around the country and have lots of sex . <unk> all about <unk> really . <unk> can see that they have no mercy for their victims . <unk> even kill a woman for her money . <unk> actresses are real porn stars in <unk> that affects the movie in two different ways . <unk> look so comfortable in sex scenes , nonetheless , they can 't make the whole film worth watching as , to me , the film does not require no further ability of acting than that . <unk> is a version of <unk> and <unk> on a different level . <unk> could recommend you loads of things to do instead of watching <unk> . <unk> , bother to watch if you wanna see a pointless , kinky film . * out of * * * * * , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.654 acc= 0.562
#
#  [200] current_iter_loss= 0.654 acc= 0.625
#
#  [300] current_iter_loss= 0.669 acc= 0.562
#
#  [400] current_iter_loss= 0.650 acc= 0.594
#
#  [500] current_iter_loss= 0.703 acc= 0.500
#
#  [600] current_iter_loss= 0.624 acc= 0.562
#
#  [700] current_iter_loss= 0.603 acc= 0.688
#
#  [800] current_iter_loss= 0.733 acc= 0.500
#
#  [900] current_iter_loss= 0.625 acc= 0.750
#
#  Epoch(5/5) avg train_loss= 0.666 train_acc= 0.596 val_loss= 0.683 val_acc= 0.581
#
#  Epoch(5/5) avg test_loss= 0.666 test_acc= 0.576
# <s> " <unk> love so much about this movie : the music , the cinematography , the acting , the story , and all the <unk> <unk> . <unk> because they are <unk> doesn 't mean they aren 't true ! <unk> is not perfect , it is a movie after all . <unk> <unk> are held in well-lit rooms with nice big <unk> and chairs , it was totally appropriate to portray it as the dark , cold scene they did in this film . <unk> also liked the scene with the angel waiting at the bus stop , smoking a cigarette . <unk> thought that was so cool . <unk> mean , <unk> believe that angels do watch over us . <unk> is one supposed to do while waiting ? <unk> is a way some people pass the time while waiting . <unk> loved the irony cause <unk> make such a deal about smoking . <unk> saw this movie 7 times in theaters in <unk> <unk> , and cried every time ! <unk> blows me away . <unk> <unk> <unk> watched it 3 times on video now and it still makes me cry every time . <unk> would jump at the chance to see it again on a big screen . <unk> hope the <unk> <unk> in <unk> <unk> will bring it back regularly at <unk> <unk> time , as a cult movie ( pun intended , but no offense intended ) . , " </s>
#
#  Pred: positive, Ans: positive

# %% [markdown]
# ## Let's Do it

# %%
config = {
  "epochs": 3,
  "hidden_size": 64,
  "bidirectional": True,
  "num_layers": 3,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 128,
  "learning_rate": 0.001,
}

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model2 = Sentiment_Classification(config, vocab_size=len(vocab))
model2 = model2.to(device)
optimizer = torch.optim.Adam(model2.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = sentiment_trainer(model2,optimizer, loaders, epoch,config["epochs"])
    evaluate(model, test_data_loader, epoch,config["epochs"], id2word)
# Out:
#  [100] current_iter_loss= 0.705 acc= 0.406
#
#  [200] current_iter_loss= 0.680 acc= 0.594
#
#  [300] current_iter_loss= 0.709 acc= 0.375
#
#  [400] current_iter_loss= 0.681 acc= 0.562
#
#  [500] current_iter_loss= 0.699 acc= 0.531
#
#  [600] current_iter_loss= 0.714 acc= 0.469
#
#  [700] current_iter_loss= 0.574 acc= 0.812
#
#  [800] current_iter_loss= 0.651 acc= 0.688
#
#  [900] current_iter_loss= 0.646 acc= 0.719
#
#  Epoch(1/3) avg train_loss= 0.681 train_acc= 0.557 val_loss= 0.668 val_acc= 0.586
#
#  Epoch(1/3) avg test_loss= 0.652 test_acc= 0.607
# <s> " <unk> is absolutely the best 80s cartoon ever , maybe the best cartoon of all time . <unk> had everything action , adventure , thrill , and much more <unk> <unk> can 't imagine how hard it was for <unk> company to make this great cartoon , there has been spent a lot of money for this masterpiece of work and it was worth it , for example just the beaming down scenes were hard because <unk> <unk> 't call the 1980s for a great technology year with computers like now in the world we live in so the beaming down scenes were excellent ! <unk> cartoons will never be the same as they were before , that is why <unk> hope that they all will be released on <unk> specially <unk> <unk> as it 's my favorite . <unk> have the whole complete set of 65 episodes on <unk> but it 's not the same because if they were released on <unk> the people in the world would be able to buy it and see the <unk> 's in almost every store which means a lot to the fans . <unk> good friend <unk> made this petition to either get the show back on <unk> or better on <unk> , that is if we get many requests to get them back on <unk> please help us by signing the petition at http : / / <unk> / <unk> / <unk> , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.606 acc= 0.719
#
#  [200] current_iter_loss= 0.615 acc= 0.656
#
#  [300] current_iter_loss= 0.636 acc= 0.594
#
#  [400] current_iter_loss= 0.579 acc= 0.719
#
#  [500] current_iter_loss= 0.614 acc= 0.562
#
#  [600] current_iter_loss= 0.638 acc= 0.719
#
#  [700] current_iter_loss= 0.683 acc= 0.594
#
#  [800] current_iter_loss= 0.717 acc= 0.562
#
#  [900] current_iter_loss= 0.706 acc= 0.500
#
#  Epoch(2/3) avg train_loss= 0.651 train_acc= 0.619 val_loss= 0.693 val_acc= 0.550
#
#  Epoch(2/3) avg test_loss= 0.685 test_acc= 0.567
# <s> " <unk> warn us of the current campaign to <unk> drug users , note the nostalgia for <unk> in <unk> and remind us of our wont to profile likely terrorists . " " <unk> " " reminds us of the evils of rampant fear and distrust and the <unk> disguised as <unk> of the <unk> era . <unk> goes around <unk> <unk> <unk> ( <unk> <unk> <unk> ) becomes the unfortunate victim of hate crimes after he is mistaken for a <unk> and these attacks increase when his bride , <unk> ( <unk> <unk> ) highlights the look . <unk> rails against the false accusations when they cause him direct harm but he minds his own business . <unk> see the rise in <unk> attacks through his <unk> , a condition not completely cured by <unk> 's typical everyman role is featured again and the long road to realization that we are all connected nearly costs him his life . <unk> is it about the character <unk> portrays to us ? <unk> can 't choose to ignore the violence , hate , and bigotry because <unk> forces us to take sides . <unk> 's dilemma is that he has no alternative but to side with the mistreated and goes through hell to see it . <unk> our sadness is that most of us need to be beaten up to realize the dangers surrounding <unk> 's focus . , " </s>
#
#  Pred: negative, Ans: positive
#
#  [100] current_iter_loss= 0.685 acc= 0.531
#
#  [200] current_iter_loss= 0.721 acc= 0.438
#
#  [300] current_iter_loss= 0.693 acc= 0.531
#
#  [400] current_iter_loss= 0.666 acc= 0.656
#
#  [500] current_iter_loss= 0.700 acc= 0.531
#
#  [600] current_iter_loss= 0.708 acc= 0.469
#
#  [700] current_iter_loss= 0.758 acc= 0.406
#
#  [800] current_iter_loss= 0.659 acc= 0.656
#
#  [900] current_iter_loss= 0.703 acc= 0.469
#
#  Epoch(3/3) avg train_loss= 0.686 train_acc= 0.562 val_loss= 0.688 val_acc= 0.561
#
#  Epoch(3/3) avg test_loss= 0.685 test_acc= 0.575
# <s> " <unk> thought this was a great idea but , boy , was it poorly executed . <unk> do get a broad sense of how complex and challenging the backstage operations of a show are , but virtually no specifics about any of it works . <unk> producers don 't seem to have found any way to tell a story or give the viewer a " " <unk> . " " ( <unk> is not to say they didn 't try , but having the <unk> relate a synopsis of the <unk> cycle as the program 's narrative does nothing to tell us about the job of physically mounting an opera . ) <unk> see lots of things happening , but are told little about what it is that the people are doing and why . <unk> 's little sense of who is who , or how the various production departments fit and work together . <unk> instance , several times we hear about a problem of some sort -- one expects then to see the problem and its consequences and / or how it gets resolved . <unk> instead the filmmakers generally just cut to something else ( generally , pretty generic footage of people pushing stuff or talking into headsets . ) <unk> the film ends up feeling more like a pastiche of images that you <unk> see run under the closing credits of a show , rather than anything worth watching for its own merit . , " </s>
#
#  Pred: negative, Ans: negative
